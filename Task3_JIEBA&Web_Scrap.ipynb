# %%
#task 5: chinese segmentation of jieba
#!pip install jieba
import jieba
seg=jieba.cut("把句子中所有的可以成词的词语都扫描出来",cut_all=True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.933 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
#TASK 1: BASIC TEXT PROCESSING PIPELINE
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
texts="""When I dare to be powerful – to use my strength in the service of my vision, then it becomes less and less important whether I am afraid"""
for text in texts:
    sentences=nltk.sent_tokenize(texts)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged=nltk.pos_tag(words)
        print(tagged)
        
for text in texts:
    words=nltk.word_tokenize(texts)
    for word in words:
        word
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# ...
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]
# [('When', 'WRB'), ('I', 'PRP'), ('dare', 'VBP'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('–', 'NNS'), ('to', 'TO'), ('use', 'VB'), ('my', 'PRP$'), ('strength', 'NN'), ('in', 'IN'), ('the', 'DT'), ('service', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('vision', 'NN'), (',', ','), ('then', 'RB'), ('it', 'PRP'), ('becomes', 'VBZ'), ('less', 'RBR'), ('and', 'CC'), ('less', 'RBR'), ('important', 'JJ'), ('whether', 'IN'), ('I', 'PRP'), ('am', 'VBP'), ('afraid', 'JJ')]

# %%
#task 2: tweettokenizer
import nltk
from nltk.tokenize import TweetTokenizer
text='The party was soooo fun: D #superfun'
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'soooo', 'fun', ':', 'D', '#superfun']

# %%
#Task 3: Scrapping Data from Web
from urllib import request
url="http://www.gutenberg.org/files/2554/2554-0.txt"
response=request.urlopen(url)
raw=response.read().decode('utf8')
type(raw)
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
from urllib import request 
url = "https://timesofindia.indiatimes.com/"
html = request.urlopen(url).read().decode('utf8')
html[:60]

print(html)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd" ><html xmlns:g="http://base.google.com/ns/1.0" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><meta charset="utf-8">
# <title>News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India</title>
# <meta http-equiv="Last-Modified" content="Sunday, 01 November, 2020 04:39:33PM">
# <meta name="Last-Modified" content="Sunday, 01 November, 2020 04:39:33PM">
# <meta name="Last-Modified-Date" content="Sun, Nov 01, 2020">
# <meta name="Last-Modified-Time" content="04.39PM IST">
# <meta content="Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World." name="description">
# <meta content="News, Breaking news, Latest news, Live news, Today news, News Today, India news, English news, Politics news, Top news in India" name="keywords">
# <meta content="News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India" property="og:title">
# <meta content="Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World." property="og:description">
# <meta content="The Times of India" property="og:site_name">
# <meta content="website" property="og:type">
# <meta content="https://timesofindia.indiatimes.com" property="og:url">
# <meta content="https://static.toiimg.com/photo/47529300.cms" property="og:image">
# <meta content="26781952138" property="fb:pages">
# <meta content="556964827" property="fb:admins">
# <meta content="117787264903013" property="fb:app_id">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <meta content="ZgFICIedNvVZl5pV9EfAUeenwta9vBY0Za_GgmV4zuw" name="google-site-verification">
# <META content="b1abb36a8d5c19c9" name="y_key">
# <meta content="1E6490AA5F9D0438A03769318F2A1088" name="msvalidate.01">
# <link href="https://timesofindia.indiatimes.com" rel="canonical">
# <link hreflang="en-us" href="https://timesofindia.indiatimes.com/us" rel="alternate">
# <link hreflang="en-IN" href="https://timesofindia.indiatimes.com" rel="alternate">
# <link hreflang="x-default" href="https://timesofindia.indiatimes.com" rel="alternate">
# <meta content="noodp,noydir" name="robots">
# <script type="text/javascript">
#               var _sf_async_config = _sf_async_config || {};
#               /** CONFIGURATION START **/
#               _sf_async_config.uid = 10538; // ACCOUNT NUMBER
#               _sf_async_config.domain = 'timesofindia.indiatimes.com'; // DOMAIN
#               _sf_async_config.flickerControl = false;
#               _sf_async_config.useCanonical = true;
#               /** CONFIGURATION END **/
#               var _sf_startpt = (new Date()).getTime();
#             </script><script type="application/ld+json">
#                 {
#                 "@context": "https://schema.org/",
#                 "@type": "WebPage",
#                 "name":"TOI home page",
#                 "description": "Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World.",
#                 "speakable": {
#                     "@type": "SpeakableSpecification",
#                     "cssSelector": [".ga-headlines1"]
#                     },
#                 "url": "https://timesofindia.indiatimes.com"
#                 }
#                 </script>
# <!--geolocation:,city:-->
# <!--[if lte IE 8]>
#                 <script src="/html5.cms"></script>
# 				<![endif]-->
# <meta content="width=1000" name="viewport" id="viewport">
# <link href="https://m.timesofindia.com/" media="only screen and (max-width: 480px)" rel="alternate">
# <link rel="alternate" href="android-app://com.toi.reader.activities/toi.index.deeplink/HomeL1/Top-01">
# <link href="https://m.timesofindia.com/amp_home" rel="amphtml">
# <script type="text/javascript">
# 			    (function(doc) {
#                     var viewport = document.getElementById('viewport');
# 			        var outerWidth=window.outerWidth;
#                     if ( navigator.userAgent.match(/iPad/i) || (outerWidth>=768 && outerWidth<=999)) {
#                         viewport.setAttribute("content", "initial-scale=1.0, width=device-width");
#                     }
#                 }(document));
#                 var hdomain='indiatimes.com';
#                 if (document.domain != hdomain)
#                 {if ((document.domain.indexOf(hdomain)) != -1)
#                 {document.domain = hdomain}}
# 			 var nsShowCook = 0<!--/interstitial_max_count.cms?geolocation=potime:35-->;
#
#
# 			if(document.cookie.match(/(?:\s)?geostate=(\w+);?/) && (document.cookie.match(/(?:\s)?geostate=(\w+);?/)[1]==='MP' || document.cookie.match(/(?:\s)?geostate=(\w+);?/)[1]==='DL')){nsShowCook=10;}
#
#             var navmsid='122455';
#             var s='0'||'';</script>
# <link crossorigin="anonymous" type="font/woff2" href="https://fonts.googleapis.com/css?family=Roboto:400,100,400italic,500,500italic,700,700italic" as="font" rel="preload">
# <link as="image" href="https://static.toiimg.com/photo/47958754.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/34824568.cms" rel="prefetch">
# <link as="image" href="https://timesofindia.indiatimes.com/photo/34824568.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/57270049.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/68845811.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/53518310.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/35958799.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/63895280.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/65796589.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/69822060.cms" rel="prefetch">
# <link as="script" rel="prefetch" href="/homejs/minify-1,version-455.cms">
# <link as="script" rel="prefetch" href="/ticker/version-9,minify-1.cms">
# <link as="script" rel="prefetch" href="/js_browser_v1.cms">
# <link as="script" rel="prefetch" href="/pn/version-39,minify-1.cms">
# <link as="script" rel="prefetch" href="/toi_js_ads/version-48,minify-1.cms">
# <link as="script" rel="prefetch" href="/videos/jquery_1_11_0_min/version-14,minify-1.cms">
# <link media="screen" type="text/css" rel="stylesheet" href="/base_header_css/version-165,minify-1.cms">
# <link as="style" href="/homecss/version-399,minify-1.cms" rel="preload">
# <link href="/homecss/version-401,minify-1.cms" media="screen" type="text/css" rel="stylesheet">
# <link rel="shortcut icon" href="https://timesofindia.indiatimes.com/icons/toifavicon.ico" type="image/x-icon">
# <!--commonlib : 404 :: 1-->
# <script type="text/javascript">
#     	    toiprops = window.toiprops || {};
#     	    toiprops.imgdomain = 'https://static.toiimg.com';
#
#                 toiprops.msid = '4719157'
#
#             toiprops.seoLocation = '';
#             toiprops._SCN_pg = (toiprops._SCN_pg)?toiprops._SCN_pg:'Default';
#         	toiprops.useSSL = 'https:' == document.location.protocol;
#         	toiprops.bot=/bot|googlebot|crawler|spider|robot|crawling/i.test(navigator.userAgent)
#
#                     toiprops.subsec1 = 47191571;
#                     toiprops._SCN_pg = 'Default';
#                     toiprops._Tmpl_pg = 'Default';
#                     toiprops._AB_version = 'WEB-HPV2';
#                 </script><script src="https://timesofindia.indiatimes.com/videos/jquery_1_11_0_min/version-15,minify-1.cms"></script><script type="text/javascript">
#                     toiprops.adFreeLayerSections=1;
# 	        </script><script type="text/javascript">
#
#     	            if (window._geo != 5 && window._geo != 1) {
#                         toiprops.toiprebid=1;
#                     }
#
# 	        </script>
# <link href="//b.scorecardresearch.com" rel="dns-prefetch">
# <link href="//b.scorecardresearch.com" rel="preconnect">
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch">
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect">
# <link href="//pubads.g.doubleclick.net" rel="dns-prefetch">
# <link href="//pubads.g.doubleclick.net" rel="preconnect">
# <link href="//www.google-analytics.com" rel="dns-prefetch">
# <link href="//www.google-analytics.com" rel="preconnect">
# <link href="//www.googletagservices.com" rel="dns-prefetch">
# <link href="//partner.googleadservices.com" rel="dns-prefetch">
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch">
# <link href="//cm.g.doubleclick.net" rel="dns-prefetch">
# <link href="//static.chartbeat.com" rel="dns-prefetch">
# <link href="//timesofindia.indiatimes.com" rel="dns-prefetch">
# <link href="//timesofindia.indiatimes.com" rel="preconnect">
# <link href="//static.toiimg.com" rel="dns-prefetch">
# <link href="//static.toiimg.com" rel="preconnect">
# <script type="text/javascript" src="/gdpr_js/version-12,minify-1.cms"></script>
# <link media="screen" type="text/css" rel="stylesheet" href="/gdpr_css/version-14,minify-1.cms">
# <script type="text/javascript">
# 	var page = false;
#
#         page = true;
#
#
#
#
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#
#             ga('create', 'UA-198011-4', 'auto', {'allowLinker': true});
#             var __ssoid = document.cookie.match(/(?:\s)?ssoid=(\w+);?/);
#             var __prc = document.cookie.match(/(?:\s)?prc=(\w+);?/);
#             if(!!(__ssoid)) {
#                 ga('set', 'userId', __ssoid[1]);
#                 ga('set', 'dimension21', 1);
#                 ga('set', 'dimension22', __ssoid[1]);
#                 ga('set', 'dimension10', ((__prc && __prc[1]) ? __prc[1] : 0));
#             }
#             else{
#                 /*For not logged-in user passing -1 - JIRA:TOIPR-45894*/
#                 ga('set', 'dimension10', -1);
#                 ga('set', 'dimension21', 0);
#             }
#             ga('require', 'linker');
#             ga('linker:autoLink', ['timesofindia.com', 'gocricket.com'] );
#             ga('require', 'displayfeatures');
#
#
#                         ga('require', 'GTM-KCRX3PN');
#
#
#                     ga('set', 'dimension8', 'HomePage');
#
#
#           ga('set', 'dimension9', 'homepage');
#
#
#         if (window.TimesGDPR && TimesGDPR.common.consentModule.gdprCallback){
#             TimesGDPR.common.consentModule.gdprCallback(function(dataObj){
#                 if (dataObj.isEUuser){
#                     ga('set', 'anonymizeIp', true);
#                 }
#
#
#                     ga('send', 'pageview');
#
#
#             });
#         }else{
#             /*
#             *geo ip call failed
#             * show EU
#             */
#             ga('set', 'anonymizeIp', true);
#
#
#                 ga('send', 'pageview');
#
#
#         }
#         var _gaq = Object();
#         _gaq.push = function(ob){
#         	try{
#         	    if(ob[0]=="_trackPageview"){
#
#
#                     ga('send', 'pageview', ob[1]?ob[1]:undefined);
#
#
#         	    }else if(ob[5]){
#         	        ga('send', 'event', ob[1]?ob[1]:undefined, ob[2]?ob[2]:undefined, ob[3]?ob[3]:undefined, {'nonInteraction': 1});
#         	    }else{
#         	        ga('send', 'event', ob[1]?ob[1]:undefined, ob[2]?ob[2]:undefined, ob[3]?ob[3]:undefined, ob[4]?ob[4]:undefined, ob[5]?ob[5]:undefined);
#         	    }
#         	}catch(e){}
#         };
#         //-- Begin comScore Tag --
#
#          window._comscore = window._comscore || [];
#         if (window.TimesGDPR  && TimesGDPR.common.consentModule.gdprCallback){
#             TimesGDPR.common.consentModule.gdprCallback(function(dataObj){
#                 var objComScore = { c1: "2", c2: "6036484" }
#                 if (dataObj.isEUuser){
#                     objComScore['cs_ucfr'] = 0;
#                 }
#                 window._comscore.push(objComScore);
#                 function fireComscore(){
#                     (function() {
#             		    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             		    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#             		    el.parentNode.insertBefore(s, el);
#         		    })();
#         		}
#         		window.fireComscore = fireComscore;
#         		fireComscore();
#         		toiprops = window.toiprops || {};
#                 toiprops.comscoreParams = objComScore;
#             });
#         }
#         else
#         {
#             window._comscore = window._comscore || [];
#             function fireComscore(){
#     		  window._comscore.push({ c1: "2", c2: "6036484", 'cs_ucfr': 0 });
#     		  (function() {
#     		    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     		    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     		    el.parentNode.insertBefore(s, el);
#     		  })();
#     		}
#     		fireComscore();
#     		toiprops = window.toiprops || {};
#             toiprops.comscoreParams = { c1: "2", c2: "6036484", 'cs_ucfr': 0 };
#         }
#         //-- End comScore Tag --
#
#
# 	    </script>
# <!--IN Home LIB :-->
# <style>.all-sections{dislay:none;}</style>
# <link rel="manifest" href="/pn_manifest.cms?v=1">
# <script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" async="true" type="text/javascript"></script><script type="text/javascript" data-cfasync="false">(function(w, d) { var s = d.createElement('script'); s.src = '//delivery.adrecover.com/39799/adRecover.js?ts=1570619213772'; s.type = 'text/javascript'; s.async = true; (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s); })(window, document);</script>
# <link href="/prime_banner_css/version-6,minify-1.cms" media="screen" type="text/css" rel="stylesheet"></head><body bgcolor="#EBEBEB" data-page-name="HP">
# <!--geolocation: -->
# <div id="container">
# <style>
# 				     .top_strip{margin:0px auto; }
# 				        .bgImg .top_strip{background:0}
# 				        div#content { z-index: 0 !important; position: static !important; background:none !important;}
# 				        @media screen and (min-width: 768px) and (max-width: 999px) {
# 				       .top_strip{display:none;}
# 				   }
#
# 				    .esi_container{
#     			        width: 100%!important;
#     			        margin-right: 0!important;
#     			    }
# 				</style>
# <!--::::-->
# <div id="div-gpt-ad-1485328452688-0-topband" data-size="[1000, 60]" data-isactive="top_band" data-adsslot="TOI/TOI_ROS_TOP_Strip_1000x60" class="webonly alC"></div>
# <div style="display:none" class="" id="login-popup">
# <button class="close-btn primeclose-btn" type="button">
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 12 12" height="12" width="12">
# <g fill-rule="evenodd" fill="none">
# <path transform="translate(-6 -6)" d="M0 0H24V24H0z"/>
# <path transform="translate(-6 -6)" d="M13.157 12l4.602-4.6a.817.817 0 000-1.16.817.817 0 00-1.157 0L12 10.843 7.398 6.24a.815.815 0 00-1.157 0 .817.817 0 000 1.159l4.602 4.6-4.602 4.6a.817.817 0 000 1.158c.32.322.837.32 1.157 0L12 13.157l4.602 4.6a.814.814 0 001.157 0 .817.817 0 000-1.157L13.157 12z" fill-rule="nonzero" fill="#999"/>
# </g>
# </svg></button>
# <div class="toggle" id="user-sign-in"></div>
# </div>
# <link href="/timespoint_css/version-11,minify-1.cms" rel="stylesheet" type="text/css"><div class="timespoint-wrapper"><div id="times-point-modal"><button type="button" class="close-btn">+</button><h2><i class="icon tp-sprite"></i>TOI TimesPoints</h2><div class="inner-container"><div class="box tab-container"><input checked class="tab" name="tabGroup" id="tab1" type="radio"><label for="tab1">HOW TO EARN</label><input class="tab" name="tabGroup" id="tab2" type="radio"><label for="tab2">MY ACTIVITY</label><input class="tab" name="tabGroup" id="tab3" type="radio"><label for="tab3">FAQs</label><div class="tab-content how-to"><div class="tp-list-wrapper"><ul class="tp-list tp-loading"></ul><div class="text-center"><button class="more-btn" type="button">more</button></div></div><div class="tp-box2"><h4>DAILY CHECK-INS: <strong><span class="checkin-days">0</span>/5 completed</strong></h4></div><div class="checkin-list"><div class="btn-grp"><button class="tp-sprite btn prev" type="button"></button><button class="tp-sprite btn next" type="button"></button></div><div class="checkin-parent tp-loading"></div></div><div style="display:none;" class="point-box checkin-info-login"><p>You must login to keep earning daily check-in points</p></div><div class="point-box checkin-info"><p></p></div><div id="widget-banner"></div><div class="offers-detail"><div class="tp-box2 flexbox justify-between align-center"><h4 data-link="https://www.timespoints.com/products">REDEEM YOUR TIMES POINTS</h4><a rel="noopener nofollow noreferrer" target="_blank" class="view-all-btn" href="https://www.timespoints.com/products?utm_source=TOI&amp;utm_medium=timespoint&amp;utm_campaign=daily_checkin">VIEW ALL</a></div><div class="gift-cards"><ul class="tp-loading"></ul></div></div></div><div class="tab-content activity"><div class="profile"><div class="inner tp-loading"><div class="profile-header flexbox justify-between align-center"><figure><img src="https://static.toiimg.com/photo/63379366.cms"></figure><div class="details"><h3 data-userdetails="name"></h3></div></div><div class="tp-details"><ul class="flexbox"><li><p>Lifetime</p><h3 data-userdetails="lifetime">0</h3></li><li><p>Expired</p><h3 data-userdetails="expired">0</h3></li><li><p>Redeemed</p><h3 data-userdetails="redeemed">0</h3></li></ul></div><div class="tp-footer"><p>Total redeemable TimesPoints</p><div class="flexbox justify-between align-center"><div class="points"><i class="tp-sprite icon"></i><span data-userdetails="redeemable">0</span></div><a class="redeem-btn tp-redeem" href="javascript: void(0)">redeem</a></div></div></div><p class="token-expiry">* TimesPoints expire in 1 year from the day of credit</p></div><div class="tp-box2 flexbox justify-between align-center"><h4>TODAY&rsquo;S ACTIVITY</h4><p class="tp-loading" id="tp-todays-date"></p></div><ul class="tp-list tp-loading"></ul></div><div class="tab-content faq"></div></div><div class="redeem-points-sticky tp-sprite"><a class="tp-btn tp-redeem" href="javascript: void(0)">REDEEM POINTS</a></div></div></div></div><div id="timespoint-popup"><div class="wrapper"><button class="close-btn" type="button"></button><div class="column"><h2><i class="icon tp-sprite"></i><span id="tp-popup-achieved-text">Visit TOI Daily &amp; Earn Times Points</span><span class="check-in-str-popup"></span></h2></div><div class="column bonusWrapper"><div class="tpPointsToolTip"></div><ul class="daily-points"></ul></div><div class="column"><a class="tp-btn" href="javascript:void(0)">KNOW MORE</a></div></div></div><script>
#             $('#times-point .close-btn').click(function() {
#                 $('.timespoint-wrapper').hide();
#             });
#         </script><!--/timespoint_html.cms?v=23potime:4-->
# <div class="top-area">
# <div class="container">
# <div class="row">
# <div class="column">
# <p>Sun, Nov 01, 2020 | Updated 04.39PM IST</p>
# </div>
# <div class="column">
# <div id="widget-head"></div>
# <div class="user_area clearfix">
# <span style="display:none;float:left;" data-plugin="user-isloggedin">
# <div class="user-controls">
# <span class="user_name">HI, <span data-plugin="user-name"></span><i class="icon_down "></i></span>
# <div class="dropdown">
# <ul>
# <li>
# <a pg="#Click-Edit_Profile-1~Header-User_Profile" target="_blank" href="https://jsso.indiatimes.com/sso/identity/profile/edit?channel=toi">Edit Profile</a>
# </li>
# <li>
# <a pg="#Click-My_Times-2~Header-User_Profile" rel="nofollow" href="http://mytimes.indiatimes.com/?channel=toi" target="_blank">My Times</a>
# </li>
# <li class="tp-redeem">
# <a pg="#Click-TP_Redeem-3~Header-User_Profile" rel="nofollow" href="https://www.timespoints.com/#/products?utm_source=TOI&amp;utm_medium=Header_Dropdown&amp;utm_campaign=TOI_HeaderDropdown" target="_blank">Redeem</a>
# </li>
# <li>
# <span pg="#Click-Logout-4~Header-User_Profile" data-plugin="user-logout">LOGOUT</span>
# </li>
# </ul>
# </div>
# </div>
# </span><span pg="#Click-Sign_In~Header-User_Profile" style="display:none;float:left; position: relative;" data-plugin="user-notloggedin" class="logout-window"><span data-plugin="user-login" class="login">Sign In</span></span>
# </div>
# <span data-plugin="nt-centre" class="noti-cnt"><span data-pgTemplate="#Open~Header-Notification" class="jNtBell"><span class="sprite_bg nt"></span><span class="noti-count"></span></span>
# <div class="gd-notification noimageNt">
# <div class="gn-notifyouter jNtDropdown" data-id="dn-nfouter">
# <div class="notification_title">Notification Center</div>
# <div class="jNtList notification-message">
# <div class="jNotificationMsgTemplate mCustomScrollbar _mCS_4">
# <a href="#0">
# <div pg="#Story_View~Header-Notification" class="notify-list">
# <figure class="ntCenterThumb">
# <img src="https://static.toiimg.com/photo/34824568.cms" data-imgsrctemplate="https://static.toiimg.com/thumb/imgsize-193484,msid-#msid#,width-200,resizemode-4/#msid#.jpg" class="jNtThumb"></figure>
# <div class="ntMsgInnerBox">
# <div rodate="" class="text"></div>
# <div class="text jNtText"></div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </span>
# <ul class="sociable">
# <li class="sprite_bg twitter">
# <a href="https://twitter.com/timesofindia" rel="nofollow" pg="#Click-twitter-1~Header-Social" target="_blank"></a>
# </li>
# <li class="sprite_bg fb">
# <a href="https://www.facebook.com/TimesofIndia" rel="nofollow" pg="#Click-fb-2~Header-Social" target="_blank"></a>
# </li>
# <li class="sprite_bg rss">
# <a href="https://timesofindia.indiatimes.com/rss.cms" pg="#Click-rss-4~Header-Social"></a>
# </li>
# <li class="sprite_bg youtube">
# <a rel="nofollow" href="https://www.youtube.com/user/TimesOfIndiaChannel" pg="#Click-youtube5~Header-Social" target="_blank"></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <link media="screen" type="text/css" rel="stylesheet" href="/css_eventspecial/hcls-whiterock,version-70,minify-1.cms"><header id="header" class="sec- whiterock"><div class="main-area"><div class="container"><a class="mobiletopnav" href="javascript:void(0);"></a><div itemtype="https://schema.org/Organization" itemscope="itemscope" itemprop="publisher" class="logo"><meta content="https://timesofindia.indiatimes.com" itemprop="url"><a pg="#Click~Header-Logo" class="main-sprite" href="/"></a><span itemtype="https://schema.org/ImageObject" itemscope="itemscope" itemprop="logo" class="category"><meta content="https://static.toiimg.com/photo/msid-58127550/toilogo.jpg" itemprop="url"><meta content="600" itemprop="width"><meta content="60" itemprop="height"></span><meta content="Times of India" itemprop="name"></div><div class="header-ad"><div class="webonly" data-size="[728, 90]" id="div-gpt-ad-toi-ros-head" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_ATF_728"></div></div></div></div><div class="bottom-area"><div class="container"><div id="allmenu-content" class="allmenu-content"></div><nav id="main-nav"><ul itemtype="http://www.schema.org/SiteNavigationElement" itemscope="itemscope" class="hpnav-ul"><li data-menu-type="two-column" data-id="home" class="nav-home" id="nav-home"><a pg="#Section_View-1~NavBar-level0-Home" href="/"></a><meta itemprop="name" content="Home"><meta itemprop="url" content="https://timesofindia.indiatimes.com"></li><li data-id="48986328" data-menu-type="top-stories" class="nav-Briefs" data-preload="" data-params="preload=1"><a href="/briefs" pg="NavBar-level0-Briefs#Section_View-2">Briefs</a><meta itemprop="name" content="Briefs"><meta itemprop="url" content="https://timesofindia.indiatimes.com/briefs"><div class="dropdown  nav-loading top-stories"></div></li><li data-id="prime_nav" class="nav-TOIPlus toiplus toimainmenu  no-hover"><a href="/toi-plus" pg="NavBar-level0-TOIPlus#Section_View-3">TOIPlus</a><meta itemprop="name" content="TOIPlus"><meta itemprop="url" content="https://timesofindia.indiatimes.com/toi-plus"><div class="dropdown  nav-loading top-stories"></div></li><li data-id="3812890" data-menu-type="two-column" class="nav-Videos"><a href="/videos" pg="NavBar-level0-Videos#Section_View-4">Videos</a><meta itemprop="name" content="Videos"><meta itemprop="url" content="https://timesofindia.indiatimes.com/videos"><div class="dropdown two-column"><div class="left-column simple-list"><ul><li data-id="4762524"><a href="/videos/top-videos" pg="NavBar-level0-Videos/level1-Top#Section_View-1">Top</a></li><li data-id="3812890"><a href="/videos/trending-videos" pg="NavBar-level0-Videos/level1-Trending#Section_View-2">Trending</a></li><li data-id="3812908"><a href="/videos/entertainment" pg="NavBar-level0-Videos/level1-Entertainment#Section_View-3">Entertainment</a></li><li data-id="77651310"><a href="/videos/astrology" pg="NavBar-level0-Videos/level1-astrology#Section_View-4">astrology</a></li><li data-id="68200753"><a href="/videos/toi-originals" pg="NavBar-level0-Videos/level1-TOI_Originals#Section_View-5">TOI Originals</a></li><li data-id="3812907"><a href="/videos/news" pg="NavBar-level0-Videos/level1-India#Section_View-6">India</a></li><li data-id="68494225"><a href="/videos/amazing-but-true" pg="NavBar-level0-Videos/level1-Amazing_but_true#Section_View-7">Amazing but true</a></li><li data-id="72276370"><a href="/videos/toi-in-depth" pg="NavBar-level0-Videos/level1-Toi_In-Depth#Section_View-8">Toi In-Depth</a></li><li data-id="69646521"><a href="/videos/times-property" pg="NavBar-level0-Videos/level1-Times_property#Section_View-9">Times property</a></li><li data-id="57448618"><a href="/videos/humour" pg="NavBar-level0-Videos/level1-Humour#Section_View-10">Humour</a></li><li data-id="59192346"><a href="/videos/city" pg="NavBar-level0-Videos/level1-City#Section_View-11">City</a></li><li data-id="68200730"><a href="/videos/international" pg="NavBar-level0-Videos/level1-International#Section_View-12">In ...
#             <ul>
#                 {{for items}}
#                 <li data-id="{{:catkey}}">
#                     <a href="{{:link}}">
#                         {{:section}}
#                     </a>
#                 </li>
#                 {{/for}}
#             </ul>
#         </script><script id="multi-list-menu-tmpl" type="text/x-jsrender">
#             {{for lists}}
#                 <h4 class="list-title">{{:title}}</h4>
#                 <ul>
#                     {{for items}}
#                         <li data-id="{{:catkey}}">
#                             <a href="{{:link}}">
#                                 {{:section}}
#                             </a>
#                         </li>
#                     {{/for}}
#                 </ul>
#             {{/for}}
#         </script><script id="two-column-menu-tmpl" type="text/x-jsrender">
#             {{if items.length}}
#                 <ul {{if items[activeIndex].className}}class="gallery {{:items[activeIndex].className}}"{{/if}} {{if items[activeIndex].catkey == 'gadgets'}}class="links-list"{{/if}}>
#                     {{for items[activeIndex].stories ~class=items[activeIndex].className ~domain=items[activeIndex].domain}}
#                         <li {{if !imageurl}}class="no-img"{{/if}}>
#                             <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}" title="{{:title}}>
#                                 {{if ((#index === 0) || (~class === 'videos') || (~class === 'photos'))}}
#                                 <img data-src="{{:imageurl}}" src="https://static.toiimg.com/photo/34824568.cms" alt="{{:title}}" />
#                                 {{/if}}
#                                 {{if !~class}}
#                                     <span>{{:trimmedtitle}}</span>
#                                 {{/if}}
#                             </a>
#                             {{if ~class}}
#                                 <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}">{{:title}}</a>
#                             {{/if}}
#                         </li>
#                     {{/for}}
#                 </ul>
#             {{/if}}
#         </script><script id="top-stories-menu-tmpl" type="text/x-jsrender">
#             <ul {{if className}}class="gallery {{:className}}"{{/if}} {{if catkey == 'gadgets'}}class="links-list"{{/if}}>
#                 {{for stories ~class=className ~domain=domain}}
#                     <li {{if !imageurl}}class="no-img"{{/if}}>
#                         <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}" title="{{:title}}" pg="{{:pg}}">
#                             {{if (imageurl) && ((#index === 0) || (~class === 'videos') || (~class === 'photos'))}}
#                                 <img data-src="{{:imageurl}}" src="https://static.toiimg.com/photo/34824568.cms" alt="{{:title}}" pg="{{:pg}}"/>
#                             {{/if}}
#                             {{if !~class}}
#                                 <span>
#                                     {{if (trimmedtitle)}}
#                                         <span>{{:trimmedtitle}}</span>
#                                     {{else}}
#                                         <span>{{:title}}</span>
#                                     {{/if}}
#                                 </span>
#                             {{/if}}
#
#                         </a>
#                         {{if ~class}}
#                             <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}" pg="{{:pg}}">
#                                 {{if (trimmedtitle)}}
#                                     <span>{{:trimmedtitle}}</span>
#                                 {{else}}
#                                     <span>{{:title}}</span>
#                                 {{/if}}
#                             </a>
#                         {{/if}}
#                     </li>
#                 {{/for}}
#             </ul>
#         </script><script id="external-html-menu-tmpl" type="text/x-jsrender">
#             {{{html}}}
#         </script><script id="error-msg-tmpl" type="text/x-jsrender">
#             <div class="error-msg">Something went wrong. Click here to view <a href="{{:link}}">{{:title}}</a>.</div>
#         </script></div><div class="search-form"><div class="wrapper"><span class="sports-sprite search-btn jSearchLens"> + </span><div class="inner jAutoSuggestorBox"><form class="navsearchboxvalidate" name="frmsearch1" method="post" action="/search.cms" data-plugin="navsearchboxvalidate"><input tabindex="1" id="query" autocomplete="off" name="query" class="textbox jAutoSuggestorInput" type="text"><input value="search" class="submit jSearchSubmit" type="submit"><input type="hidden" value="" name="type"><input type="hidden" value="233446897" name="catkey"><input type="hidden" value="3" name="search"><input type="hidden" value="" name="sitesearch"><input type="hidden" value="1" name="fields"><input type="hidden" value="2" name="searchtype"><input type="hidden" value="2" name="article"><input value="0" type="hidden" name="search1"><br class="clearfix"></form><ul class="searchSuggestions" id="nav_autosuggest_result"></ul></div></div></div></div></header><!--/base_header.cms?version=202&msid=4719157&homepage=TOIHP&head=showleft&rosad=TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_ATF_728&pv=70&hcls=whiterockpotime:6-->
# <script type="text/javascript" src="/ads.cms"></script><script type="text/javascript">
#                 		    $( window ).load(function() {
#                 		        if(typeof window.canRun === "undefined") {
#                 		            $('.header-ad').html('<a href="https://recipes.timesofindia.com/" pg="adblocker#header-ad" target="_blank"><img src="https://static.toiimg.com/photo/66648361.cms" alt="Thousands of Recipes" width="728"></a>')
#                 		        }
#                             });
#                 		</script>
# <div class="adsdivlyr" id="adsdivLyr"></div>
# <div style="opacity: 0; height: 0px;" id="tileyeDiv"></div>
# <div class="adsdivlyr" name="netspidersosh" id="netspidersosh"></div>
# <div id="content">
# <div class="wrapper clearfix">
# <div data-fallback-ad-for="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov1" data-size="[[125, 600], [120, 600]]" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_RHS_125" id="div-gpt-ad-1498641584608-0" style="top:10px;position:fixed;margin-left: 1006px; cursor: pointer; z-index: 1; " class="ros_skinning_rhs webonly"></div>
# <div data-fallback-ad-for="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov1" data-size="[[125, 600], [120, 600]]" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_LHS_125" id="div-gpt-ad-1547448597970-0" style="top:10px;position:fixed;margin-left: -131px; cursor: pointer; z-index: 1; " class="ros_skinning_lhs webonly"></div>
# <style xmlns:g="http://base.google.com/ns/1.0">
#             .liveS_container .close_s{display: block; border: 0; color: #999; text-decoration: none; cursor: pointer; float: right; position: relative; line-height: 22px; margin:3px 10px 1px; box-sizing: border-box;}
# 				.liveS_container .close_s:before{content: "+"; transform: rotate(135deg); font-size: 27px; font-weight: 300; display: block;}
# 				.liveS_container .close_s:hover{text-decoration: none}
#         </style><script>
#            var miniTVType = 'livetvvideo';
# 		    var miniTVScope = '';
# 		    var entertainmentSections = ['1081479906','27975577','2886704'];
# 		    var sponsoredTitle = "";
# 		    var miniTVTitle = "Actor Boman Irani is e-learning at 60!";
# 		    var sponsoredTitleFull = '';
# 		    sponsoredTitle = sponsoredTitle.substring(0,77)+"...";
#
# 		    var isSponsorVideoPlaying = false;
#
#
#
#        </script><script>
#              window.top.adsCallback = function(adtype){
#                     if(typeof adtype!='undefined' && adtype =="gutterclose"){
#                          try{if(primePaymentFlow){primePaymentFlow.show_ad_free_nudge(true)} }catch(e){}
#                     }
#                     if(typeof adtype!='undefined' && adtype =="expandoclose"){
#                         try{if(primePaymentFlow){primePaymentFlow.show_ad_free_nudge(true)}}catch(e){}
#                     }
#                  if(typeof adtype!='undefined' && adtype =="sponsorVid"){
#                    // $(document.getElementById("minitv")).find(".close_v").click();
#                     $(document.getElementById("player")).attr("src", "/sponsortv.cms");
#                  }
#                      if(typeof adtype!='undefined' && adtype =="gutter"){
#              setTimeout(function(){if(typeof redraw_graphs_pollution === 'function'){redraw_graphs_pollution();}},1000);
#              }
#              }
#        </script><input id="specialId_forGeoEvent" type="hidden" value=""><input id="matchId" type="hidden" value="1xp71exk6u"><div id="minitv" data-pagename="home" data-showlivetv="1" data-showevent="0"></div><script src="https://geoapi.indiatimes.com/?cb=1" type="text/javascript"></script><script>
#
# 			    function registerSponsorVid(){
#                     window.console && console.log("*** registerSponsorVid");
#                         setTimeout(function(){
#                             $(document).trigger('MINI_TV_REGISTER', [{source:'sponsorVid'}, 'MINI_TV_LOADED', function(){}]);
#                             $(document).trigger('MINI_TV_EVENTS', [{source: "sponsorVid",id:''}, "VIDEOREADY"]);
#                         }, 100);
#                         setTimeout(function(){
#                             $(document).trigger('MINI_TV_EVENTS', [{source: "sponsorVid",id:''}, "PLAYING"]);
#                         }, 300);
#                 }
# 			    var isMobileDevice = function () {
#                     return (function (a) {
#                         return /(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(a) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0, 4));
#                     })(navigator.userAgent || navigator.vendor || window.opera);
#                 }
#                 var isTablet = function () {
#             		return( function ( agent ) {
#             			return /(?:ipad|tab)/i.test( agent );
#             		} )( navigator.userAgent || navigator.vendor || window.opera );
#             	}
# 				var miniTV = Object();
# 				miniTV.ajax = function(url,callback){
# 					$.get( url, function( data ) {
# 						callback( data );
# 					});
# 				};
# 				miniTV.hideMiniTvAndLabel = function(){
# 				    $('.livetv_box_label').hide();
#                     $('.livetv_box').hide();
# 				};
# 				miniTV.preinit = function(){
#                   var showLiveTv = $('#minitv').attr('data-showlivetv');
#                   var pagename = $('#minitv').attr('data-pagename');
#                   if(showLiveTv && parseInt(showLiveTv)){
#                       if(pagename == 'home'){
#                        var showLiveTvEvent =  $('#minitv').attr('data-showevent');
#                           switch(showLiveTvEvent){
#                             case 'onscroll':
#                                miniTV.loadLiveTvOnScroll();
#                                break;
#                             case 'timeout':
#                                   setTimeout(miniTV.isOn, 10000);
#                                  break;
#                             default:
#                                 miniTV.isOn();
#                           }
#                       }else{
#                         miniTV.isOn();
#                       }
#                   }
#                 };
# 				miniTV.throttleLiveTvEvents = function(func,limit){
#                  var inThrottle;
#                   return function() {
#                     var context = this;
#                     if (!inThrottle) {
#                       func.call(context);
#                       inThrottle = true;
#                       setTimeout(function(){inThrottle = false; }, limit);
#                     }
#                   }
#                 };
#                 miniTV.loadLiveTvOnScroll = function(){
#                     $(window).on('scroll.livetvinit', function(){
#                             var scrollTop = $(window).scrollTop();
#                             var throttledCb = miniTV.throttleLiveTvEvents(function(){
#                                 if(scrollTop>=600){
#                                    miniTV.isOn();
#                                   $(window).off('scroll.livetvinit');
#                                 }
#                             }, 200);
#                             throttledCb();
#                     });
#                 };
# 				miniTV.isOn = function(){
# 				    if(isMobileDevice() || isTablet() || window.frmapp) {
# 				        return;
# 				    }
#
#
# 				    var url='https://toibnews.timesofindia.indiatimes.com/TOIBNews/home_topcontent_banner.htm';
# 				    if(window.location.host.match(/toidev|jcmsdev/)){
# 				        var pagename = $('#minitv').attr('data-pagename');
# 				        url='/home_topcontent_banner.cms?pagetype=isEnabled&pagename='+pagename;
# 				    }
#
#
#
# 					miniTV.ajax(url,function(data){
# 						data = $.trim(data);
# 						var geoinfo = window.geoinfo;
#             	        var countryCode = ( geoinfo.CountryCode || "" ).toUpperCase();
#             	        var specialId_forGeoEvent =  ( $("#specialId_forGeoEvent").val() || "" ).toUpperCase();
#             	        var matchId = $("#matchId").val() || "";
#             	        if(
#             	            specialId_forGeoEvent
#             	            && countryCode != specialId_forGeoEvent
#             	        ){
#             	            miniTV.hideMiniTvAndLabel();
#                             return;
#             	        }else if( countryCode == 'HK' ){
#             	            miniTV.hideMiniTvAndLabel();
#             	            return;
#             	        }
#
# 						if(toiprops.cookie.get('playvd') && data!=''){
#
# 							$('#minitv').html(data);
# 							$(document).trigger('miniTVVisible');
#
# 							if($('#streaming_box').is(":visible") && $('.livetv_box_label').is(":visible") || $('.livetv_box').is(":visible"))
# 	                        {
# 	                            $('.livetv_box_label').hide();
# 	                            $('.livetv_box').hide();
# 	                       }
#
# 						    if (typeof miniTV.clickLoad == "function") miniTV.clickLoad();
# 						} else if (data!=''){
#
# 							$('#minitv').html(data);
# 							$(document).trigger('miniTVVisible');
#
# 						    if($('#streaming_box').is(":visible") && $('.livetv_box_label').is(":visible") || $('.livetv_box').is(":visible"))
# 	                        {
# 	                            $('.livetv_box_label').hide();
# 	                            $('.livetv_box').hide();
# 	                       }
# 						}
#
#
#         				   if(miniTVType == "sponsoredvideo" && (miniTVScope == "etimes" && ((window.parent.toiprops.subsec1!=undefined && entertainmentSections.indexOf(window.parent.toiprops.subsec1) >=0) || (window.parent.channelname != undefined && window.parent.channelname == 233446897))) && countryCode=="IN")
#         				   {
#         				         if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#         				        {
#         				        	$(".liveS_container").hide();
#         				            if (typeof miniTV.clickLoad == "function") miniTV.clickLoad();
#         				        }
#         				        $("#player").attr("src", "/sponsortv.cms");
#         				        $(".livetv_title").html(sponsoredTitle);
#         				        $(".livetv_title").attr("title",sponsoredTitleFull);
#         				        $("#streaming_box").addClass("sponsoredad");
#         				        isSponsorVideoPlaying = true;
#         				        registerSponsorVid && registerSponsorVid();
#
#         				   }
#         				   else if(miniTVType == "sponsoredvideo" && miniTVScope == "" && countryCode=="IN")
#         				   {
#         				        if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#         				        {
#         				        	$(".liveS_container").hide();
#         				            if (typeof miniTV.clickLoad == "function") miniTV.clickLoad();
#         				        }
#         				         $("#player").attr("src", "/sponsortv.cms");
#         				         $(".livetv_title").html(sponsoredTitle);
#         				         $(".livetv_title").attr("title",sponsoredTitleFull);
#         				         $("#streaming_box").addClass("sponsoredad");
#         				         isSponsorVideoPlaying = true;
#         				         registerSponsorVid && registerSponsorVid();
#         				   }
#         				    else if(miniTVType == "livetvvideo" && (miniTVScope == "etimes" && ((window.parent.toiprops.subsec1!=undefined && entertainmentSections.indexOf(window.parent.toiprops.subsec1) >=0) || (window.parent.channelname != undefined && window.parent.channelname == 233446897))))
#         				   {
#         				         $("#streaming_box").removeClass("sponsoredad");
#         				        isSponsorVideoPlaying = false;
#         				        // do nothing
#         				        if(miniTVTitle == "")
#         				        {
#
#         				            if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#             				        {
#             				        	$(".liveS_container").hide();
#             				        }
#         				        }
#
#         				   }
#         				   else if(miniTVType == "livetvvideo" && miniTVScope == "")
#         				   {
#         				        $("#streaming_box").removeClass("sponsoredad");
#         				        isSponsorVideoPlaying = false;
#         				        // do nothing
#         				        if(miniTVTitle == "")
#         				        {
#
#         				            if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#             				        {
#             				        	$(".liveS_container").hide();
#             				        }
#         				        }
#         				   }
#         				   else if(miniTVType == "livetvvideo" && miniTVScope == "ptgalso")
#         				   {
#         				        $("#streaming_box").removeClass("sponsoredad");
#         				        isSponsorVideoPlaying = false;
#         				        // do nothing
#         				        if(miniTVTitle == "")
#         				        {
#
#         				            if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#             				        {
#             				        	$(".liveS_container").hide();
#             				        }
#         				        }
#         				   }
#         				   else
#         				   {
#         				        //do nothing
#         				        $(".liveS_container").hide();
#         				        $("#minitv").hide()
#         				   }
#         				   try{ if(TimesApps.ad_free_nudge==1){$('#streaming_box').addClass("adjust_nudge")}}catch(e){}
# 					});
# 				};
#
#
# 			        setTimeout(function(){miniTV.preinit();}, 5000);
# 			    </script><!--/home_topcontent_banner.cms?pagename=home&version=15&pagetype=new&source=toipotime:7-->
# <div>
# ...
# </a></li><li><a pg="More_from_TOI-Wattpad#Story_View-4-geturl" title="Last Drop of Water
# " target="_blank" href="https://www.wattpad.com/story/219559488?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Last Drop of Water
# </a></li><li><a pg="More_from_TOI-Wattpad#Story_View-5-geturl" title="Shared Responsibilities" target="_blank" href="https://www.wattpad.com/story/219696671?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Shared Responsibilities</a></li></ul></div><div class="widget"><div class="widget-heading2 clearfix"><a class="more" href="https://www.businessinsider.in?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" pg="More_from_TOI-BusinessInsider#Section_View_More" target="_blank" rel="nofollow">more</a><h3><span><a href="https://www.businessinsider.in?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" pg="More_from_TOI-BusinessInsider#Section_View" target="_blank" rel="nofollow">Business Insider India</a></span></h3></div><ul class="list2"><li class="main-story clearfix"><figure><a href="https://www.businessinsider.in/entertainment/news/darrell-hammond-shared-a-clip-of-his-iconic-snl-sean-connery-impression-in-honor-of-the-late-james-bond-star/articleshow/78981324.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" pg="More_from_TOI-BusinessInsider#Story_View-1-geturl" rel="nofollow"><img src="https://static.toiimg.com/photo/34824568.cms" data-src="/thumb/78981324.cms" alt="Darrell Hammond shared a clip of his iconic 'SNL' Sean Connery impression in honor of the late James Bond star"></a></figure><h3><a pg="More_from_TOI-BusinessInsider#Story_View-1-geturl" title="Darrell Hammond shared a clip of his iconic 'SNL' Sean Connery impression in honor of the late James Bond star" target="_blank" href="https://www.businessinsider.in/entertainment/news/darrell-hammond-shared-a-clip-of-his-iconic-snl-sean-connery-impression-in-honor-of-the-late-james-bond-star/articleshow/78981324.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Darrell Hammond shared a clip of his iconic</a></h3></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-2-geturl" title="Heavy-hitting American boxer Gervonta Davis takes another big step to superstardom with a devastating KO win" target="_blank" href="https://www.businessinsider.in/sports/news/heavy-hitting-american-boxer-gervonta-davis-takes-another-big-step-to-superstardom-with-a-devastating-ko-win/articleshow/78981079.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Heavy-hitting American boxer Gervonta Davis</a></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-3-geturl" title="Covid vaccine trials in AMU from Nov 14" target="_blank" href="https://www.businessinsider.in/india/news/covid-vaccine-trials-in-amu-from-nov-14/articleshow/78978301.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Covid vaccine trials in AMU from Nov 14</a></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-4-geturl" title="The Biden campaign cancelled events in Texas after a convoy of trucks flying Trump flags surrounded their bus and ran into a person's car, officials say" target="_blank" href="https://www.businessinsider.in/politics/world/news/the-biden-campaign-cancelled-events-in-texas-after-a-convoy-of-trucks-flying-trump-flags-surrounded-their-bus-and-ran-into-a-persons-car-officials-say/articleshow/78977884.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">The Biden campaign cancelled events in Texas</a></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-5-geturl" title="NYC authorities shut down a packed, indoor Halloween party in Brooklyn with nearly 400 guests" target="_blank" href="https://www.businessinsider.in/international/news/nyc-authorities-shut-down-a-packed-indoor-halloween-party-in-brooklyn-with-nearly-400-guests/articleshow/78977111.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">NYC authorities shut down a packed, indoor</a ...
# <div class="loader alC">
# <img src="https://static.toiimg.com/photo/35958799.cms"></div>
# </div>
# </div>
# </div>
# </div>
# <script defer="1" src="/election_social_js/minify-1,version-4.cms" type="text/javascript"></script><script src="/prime_banner_js/version-24,minify-1.cms" type="text/javascript"></script>
# <div class="wrapper toi_cube_box" id="div-gpt-ad-1576845512809-0" data-size="[1, 1]" data-adsSlot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_Cube_1x1"></div>
# <footer class="new_footer" id="footer">
# <script>
#         (function(){
#           function pingIbeat() {
#             window._pg_endpt=(new Date()).getTime();
#             var e = document.createElement('script');
#             e.setAttribute('language', 'javascript');
#             e.setAttribute('type', 'text/javascript');
#             e.setAttribute('async', 'true');
#             e.setAttribute('src',"https://agi-static.indiatimes.com/cms-common/ibeat.min.js");
#             document.body.appendChild(e);
#           }
#           function _ccaud() {
#             var e = document.createElement('script');
#             e.setAttribute('language', 'javascript');
#             e.setAttribute('type', 'text/javascript');
#             e.setAttribute('async', 'true');
#             e.setAttribute('src',"https://ade.clmbtech.com/cde/ae/2658/var=_ccaud?_u="+encodeURIComponent(window.location.href));
#             document.body.appendChild(e);
#           }
#
#           if (TimesGDPR && TimesGDPR.common.consentModule.gdprCallback){
#                 TimesGDPR.common.consentModule.gdprCallback(function(dataObj){ //Block for EU users
#                     if (dataObj.isEUuser){_ibeat_track= {sCookie: false}}
#                     pingIbeat();
#                 });
#             }else{
#                 _ibeat_track= {sCookie: false};
#                 pingIbeat();
#             }
#             _ccaud()
#         })();
#         </script><style>
#             .video-overlay-wrapper .playlist ul.cvs_wdt li:after, .expand-overlay .playlist ul li:after{width: calc(100% + 20px); height: calc(100% + 20px); left: -10px; top: -10px;}
#         </style><div class="wrapper"><div data-cookie="geolocation" data-size="[1, 1]" data-adsSlot="TOI_Impression_Trackers/TOI_Test_Geo_1x1" data-geo="1|2|3|4|6|7|8" id="div-gpt-ad-1453295401681-0"></div><div data-size="[1, 1]" data-adsSlot="TOI/TOI_ROS/TOI_ROS_Andbeyond_1x1" id="div-gpt-ad-1559800487669-0"></div><div data-size="[1, 1]" data-geo="2|7" data-adsSlot="TOI/TOI_ROS/TOI_ROS_Undertone_1x1" id="div-gpt-ad-1559800489898-0"></div><div data-cookie="geostate" data-size="[1, 1]" data-adsSlot="TOI_Impression_Trackers/TOI_Test_Web_Geo_1x1" data-geo="1|2" id="div-gpt-ad-145329540136376-0"></div><div style="" class="row level1 clearfix"><div class="column"><div class="section"><h2><span>Other Times Group news sites</span></h2><ul><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-The_Economic_Times#Item_View-2-geturl" title="The Economic Times" href="https://economictimes.indiatimes.com" rel="nofollow">The Economic Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Hindi_Economic_Times#Item_View-3-geturl" title="Hindi Economic Times" href="https://economictimes.indiatimes.com/hindi" rel="nofollow">Hindi Economic Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Navbharat_Times#Item_View-4-geturl" title="Navbharat Times" href="https://navbharattimes.indiatimes.com" rel="nofollow">Navbharat Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Maharashtra_Times#Item_View-5-geturl" title="Maharashtra Times" href="https://maharashtratimes.com/" rel="nofollow">Maharashtra Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Vijaya_Karnataka#Item_View-6-geturl" title="Vijaya Karnataka" href="https://vijaykarnataka.com/" rel="nofollow">Vijaya Karnataka</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Telugu_Samayam#Item_View-7-geturl" title="Telugu Samayam" href="https://telugu.samayam.com/" rel="nofollow">Telugu Samayam</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Tamil_Samayam#Item_View-8-geturl" title="Tamil Samayam" href="https://tamil.samayam.com/" rel="nofollow">Tamil Samayam</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Malayalam_Samayam#Item_View-9-geturl" title="Malayalam Samayam" href="https://malayalam.samayam.com/" rel="nofollow">Malayalam Samayam</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Ei_Samay#Item_View-10-geturl" title="Ei Samay" href="https://eisamay.indiatimes.com/" rel="nofollow">Ei Samay</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-I_am_Gujarat#Item_View-11-geturl" title="I am Gujarat" href="https://www.iamgujarat.com/" rel="nofollow">I am Gujarat</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Times_Now#Item_View-12-geturl" title="Times Now" href="https://www.timesnownews.com/" rel="nofollow">Times Now</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Times_Now_Hindi#Item_View-13-geturl" title="Times Now Hindi" href="https://www.timesnowhindi.com/" rel="nofollow">Times Now Hindi</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-TimesPoints#Item_View-14-geturl" title="TimesPoints" href="https://www.timespoints.com/#/products?utm_source=TOI&amp;utm_medium=Footer&amp;utm_campaign=TOI_Footer" rel="nofollow">TimesPoints</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Indiatimes#Item_View-15-geturl" title="Indiatimes" href="https://www.indiatimes.com/" rel="nofollow">Indiatimes</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Brand_Capital#Item_View-16-geturl" title="Brand Capital" href="http://brandcapital.co.in/" rel="nofollow">Brand Capital</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Education_Times#Item_View-17-geturl" title="Education Times" href="http://www.educationtimes.com/" rel="nofollow">Education Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/le ...
#
#                     <span class="temp_h">
#                     {{if cityName}}
#                              {{:cityName}}
#                     {{/if}}
#                     </span>
#                     <span class="temp_g">
#                         <a href="/weather/city-{{:cityName}}.cms" target="_blank">
#                             <span class="icon {{:iconClass}}"></span>
#                             <span class="temp">
#                                 <span class="wdC">{{:tempC}}&#xB0;<small>C</small></span>
#                                 <span class="wdF">{{:tempF}}&#xB0;F</span>
#                             </span>
#                         </a>
#                     </span>
#                     <span class="optionshome">
#                         <a pg="#Change-Fahrenheit~Header-Weather" onclick="$('.wdF').hide();$('.wdC').show();$('#wdCid').hide();$('#wdFid').show();" style="cursor: pointer; display: none;" id="wdCid">°C</a>
#                         <a pg="#Change-Celcius~Header-Weather" onclick="$('.wdC').hide();$('.wdF').show();$('#wdFid').hide();$('#wdCid').show();" style="cursor: pointer;" id="wdFid">&#xB0;F</a>
#                     </span>
#                     <a href="/weather.cms" target="_blank" class="arrow" pg="#Click~Header-Weather">»</a>
#
#             </script><script type="text/javascript">
#
#                 (function(){
#                     var showTOIPlusinNav = false;
#                     if( (["toidev.indiatimes.com", "toistg.indiatimes.com"].indexOf(document.location.hostname) > -1) ){
#                         if(document.location.search.indexOf('geolocation=1') > -1) {
#                             showTOIPlusinNav = true;
#                         }
#                     }
#                     else if(window._geo != 'undefined' && window._geo == '1'){
#                         showTOIPlusinNav = true;
#                     }
#                     if(showTOIPlusinNav){
#                         var toiplusinNavEle = document.querySelector("#main-nav>ul>li.toiplus");
#                         if(typeof(toiplusinNavEle) != 'undefined' && toiplusinNavEle != null){
#                             document.querySelector("#main-nav>ul>li.toiplus").style.display = "inline-block";
#                         }
#                     }
#                 })();
#
#         </script><div class="wrapper"><p>Copyright &copy; 2020 Bennett, Coleman &amp; Co. Ltd. All rights reserved. For reprint rights: <a href="#">Times Syndication Service</a></p></div><!--/toifooter.cms?s=0&version=6&newlogin=potime:4-->
# <!--Server: 130-->
# <link media="screen" type="text/css" rel="stylesheet" href="/slick_css/version-1,minify-1.cms">
# <script src="/slick_min_js_v18/version-1,minify-1.cms" type="text/javascript"></script><script type="text/javascript" src="https://image.timespoints.iimg.in/static/tpsdk/tp-sdk.js"></script><script src="/jsrender/version-1.cms" type="text/javascript"></script><script src="https://jssocdn.indiatimes.com/crosswalk/jsso_crosswalk_legacy_0.5.3.min.js" type="text/javascript"></script><script defer="true" async="true" src="https://www.google.com/recaptcha/api.js"></script>
# <link href="/usermanagementcssv2/version-20,minify-1.cms" media="screen" type="text/css" rel="stylesheet">
# <script type="text/javascript" src="/toi_js/version-589,minify-1.cms"></script><script src="/pn/version-39,minify-1.cms" type="text/javascript"></script><script>
#         (function(){
#           if (TimesGDPR && TimesGDPR.common.consentModule.gdprCallback){
#                 TimesGDPR.common.consentModule.gdprCallback(function(dataObj){ //Block for EU users
#                     var showJs = !dataObj.isEUuser || (dataObj && dataObj.isEUuser && !dataObj.didUserOptOut);
#
#                     if(showJs){
#                         var pbjsEl = document.createElement("script");
#                         pbjsEl.type = "text/javascript";
#                         pbjsEl.async = true;
#                         pbjsEl.src = "https://static.clmbtech.com/ase/2658/3/aa.js";
#                         pbjsEl.onload = function(){
#
#                         }
#                         var pbjsTargetEl = document.getElementsByTagName("head")[0];
#                         pbjsTargetEl.insertBefore(pbjsEl, pbjsTargetEl.firstChild);
#                     }
#                 });
#             }
#         })();
#         </script>
# </footer>
# <script src="/homejs/minify-1,version-455.cms" type="text/javascript"></script><script type="text/javascript">
#                      $('#travelwidget .main-story').addClass("clearfix");
#                  </script>
# <div data-fallback-ads="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_RHS_125$$TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_LHS_125" data-isactive="hp_innov1" id="div-gpt-ad-TOI_HP_NW_OP_Innov1" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov1" class="webonly"></div>
# <div id="div-gpt-ad-TOI_HP_NW_OP_Innov2" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov2" class="webonly"></div>
# <div id="div-gpt-ad-TOI_HP_NW_OP_Pop" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Pop" class="webonly"></div>
# <div id="div-gpt-ad-oHP_NW_OP_Shosh" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Shosh" class="webonly"></div>
# </div>
# </body>
# <div xmlns:str="http://exslt.org/strings" class="ad-widget wdgt colombia alC" id="div-gpt-ad---" data-position="" data-slot=""></div><!--/native_content.cms?slot=129105&section=0&String=129105:1potime:6-->
# </html>

# %%
from urllib import request 
url = "https://timesofindia.indiatimes.com/"
html = request.urlopen(url).read().decode('utf8')
html[:60]

print(html)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd" ><html xmlns:g="http://base.google.com/ns/1.0" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><meta charset="utf-8">
# <title>News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India</title>
# <meta http-equiv="Last-Modified" content="Sunday, 01 November, 2020 04:39:33PM">
# <meta name="Last-Modified" content="Sunday, 01 November, 2020 04:39:33PM">
# <meta name="Last-Modified-Date" content="Sun, Nov 01, 2020">
# <meta name="Last-Modified-Time" content="04.39PM IST">
# <meta content="Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World." name="description">
# <meta content="News, Breaking news, Latest news, Live news, Today news, News Today, India news, English news, Politics news, Top news in India" name="keywords">
# <meta content="News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India" property="og:title">
# <meta content="Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World." property="og:description">
# <meta content="The Times of India" property="og:site_name">
# <meta content="website" property="og:type">
# <meta content="https://timesofindia.indiatimes.com" property="og:url">
# <meta content="https://static.toiimg.com/photo/47529300.cms" property="og:image">
# <meta content="26781952138" property="fb:pages">
# <meta content="556964827" property="fb:admins">
# <meta content="117787264903013" property="fb:app_id">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <meta content="ZgFICIedNvVZl5pV9EfAUeenwta9vBY0Za_GgmV4zuw" name="google-site-verification">
# <META content="b1abb36a8d5c19c9" name="y_key">
# <meta content="1E6490AA5F9D0438A03769318F2A1088" name="msvalidate.01">
# <link href="https://timesofindia.indiatimes.com" rel="canonical">
# <link hreflang="en-us" href="https://timesofindia.indiatimes.com/us" rel="alternate">
# <link hreflang="en-IN" href="https://timesofindia.indiatimes.com" rel="alternate">
# <link hreflang="x-default" href="https://timesofindia.indiatimes.com" rel="alternate">
# <meta content="noodp,noydir" name="robots">
# <script type="text/javascript">
#               var _sf_async_config = _sf_async_config || {};
#               /** CONFIGURATION START **/
#               _sf_async_config.uid = 10538; // ACCOUNT NUMBER
#               _sf_async_config.domain = 'timesofindia.indiatimes.com'; // DOMAIN
#               _sf_async_config.flickerControl = false;
#               _sf_async_config.useCanonical = true;
#               /** CONFIGURATION END **/
#               var _sf_startpt = (new Date()).getTime();
#             </script><script type="application/ld+json">
#                 {
#                 "@context": "https://schema.org/",
#                 "@type": "WebPage",
#                 "name":"TOI home page",
#                 "description": "Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World.",
#                 "speakable": {
#                     "@type": "SpeakableSpecification",
#                     "cssSelector": [".ga-headlines1"]
#                     },
#                 "url": "https://timesofindia.indiatimes.com"
#                 }
#                 </script>
# <!--geolocation:,city:-->
# <!--[if lte IE 8]>
#                 <script src="/html5.cms"></script>
# 				<![endif]-->
# <meta content="width=1000" name="viewport" id="viewport">
# <link href="https://m.timesofindia.com/" media="only screen and (max-width: 480px)" rel="alternate">
# <link rel="alternate" href="android-app://com.toi.reader.activities/toi.index.deeplink/HomeL1/Top-01">
# <link href="https://m.timesofindia.com/amp_home" rel="amphtml">
# <script type="text/javascript">
# 			    (function(doc) {
#                     var viewport = document.getElementById('viewport');
# 			        var outerWidth=window.outerWidth;
#                     if ( navigator.userAgent.match(/iPad/i) || (outerWidth>=768 && outerWidth<=999)) {
#                         viewport.setAttribute("content", "initial-scale=1.0, width=device-width");
#                     }
#                 }(document));
#                 var hdomain='indiatimes.com';
#                 if (document.domain != hdomain)
#                 {if ((document.domain.indexOf(hdomain)) != -1)
#                 {document.domain = hdomain}}
# 			 var nsShowCook = 0<!--/interstitial_max_count.cms?geolocation=potime:35-->;
#
#
# 			if(document.cookie.match(/(?:\s)?geostate=(\w+);?/) && (document.cookie.match(/(?:\s)?geostate=(\w+);?/)[1]==='MP' || document.cookie.match(/(?:\s)?geostate=(\w+);?/)[1]==='DL')){nsShowCook=10;}
#
#             var navmsid='122455';
#             var s='0'||'';</script>
# <link crossorigin="anonymous" type="font/woff2" href="https://fonts.googleapis.com/css?family=Roboto:400,100,400italic,500,500italic,700,700italic" as="font" rel="preload">
# <link as="image" href="https://static.toiimg.com/photo/47958754.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/34824568.cms" rel="prefetch">
# <link as="image" href="https://timesofindia.indiatimes.com/photo/34824568.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/57270049.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/68845811.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/53518310.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/35958799.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/63895280.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/65796589.cms" rel="prefetch">
# <link as="image" href="https://static.toiimg.com/photo/69822060.cms" rel="prefetch">
# <link as="script" rel="prefetch" href="/homejs/minify-1,version-455.cms">
# <link as="script" rel="prefetch" href="/ticker/version-9,minify-1.cms">
# <link as="script" rel="prefetch" href="/js_browser_v1.cms">
# <link as="script" rel="prefetch" href="/pn/version-39,minify-1.cms">
# <link as="script" rel="prefetch" href="/toi_js_ads/version-48,minify-1.cms">
# <link as="script" rel="prefetch" href="/videos/jquery_1_11_0_min/version-14,minify-1.cms">
# <link media="screen" type="text/css" rel="stylesheet" href="/base_header_css/version-165,minify-1.cms">
# <link as="style" href="/homecss/version-399,minify-1.cms" rel="preload">
# <link href="/homecss/version-401,minify-1.cms" media="screen" type="text/css" rel="stylesheet">
# <link rel="shortcut icon" href="https://timesofindia.indiatimes.com/icons/toifavicon.ico" type="image/x-icon">
# <!--commonlib : 404 :: 1-->
# <script type="text/javascript">
#     	    toiprops = window.toiprops || {};
#     	    toiprops.imgdomain = 'https://static.toiimg.com';
#
#                 toiprops.msid = '4719157'
#
#             toiprops.seoLocation = '';
#             toiprops._SCN_pg = (toiprops._SCN_pg)?toiprops._SCN_pg:'Default';
#         	toiprops.useSSL = 'https:' == document.location.protocol;
#         	toiprops.bot=/bot|googlebot|crawler|spider|robot|crawling/i.test(navigator.userAgent)
#
#                     toiprops.subsec1 = 47191571;
#                     toiprops._SCN_pg = 'Default';
#                     toiprops._Tmpl_pg = 'Default';
#                     toiprops._AB_version = 'WEB-HPV2';
#                 </script><script src="https://timesofindia.indiatimes.com/videos/jquery_1_11_0_min/version-15,minify-1.cms"></script><script type="text/javascript">
#                     toiprops.adFreeLayerSections=1;
# 	        </script><script type="text/javascript">
#
#     	            if (window._geo != 5 && window._geo != 1) {
#                         toiprops.toiprebid=1;
#                     }
#
# 	        </script>
# <link href="//b.scorecardresearch.com" rel="dns-prefetch">
# <link href="//b.scorecardresearch.com" rel="preconnect">
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch">
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect">
# <link href="//pubads.g.doubleclick.net" rel="dns-prefetch">
# <link href="//pubads.g.doubleclick.net" rel="preconnect">
# <link href="//www.google-analytics.com" rel="dns-prefetch">
# <link href="//www.google-analytics.com" rel="preconnect">
# <link href="//www.googletagservices.com" rel="dns-prefetch">
# <link href="//partner.googleadservices.com" rel="dns-prefetch">
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch">
# <link href="//cm.g.doubleclick.net" rel="dns-prefetch">
# <link href="//static.chartbeat.com" rel="dns-prefetch">
# <link href="//timesofindia.indiatimes.com" rel="dns-prefetch">
# <link href="//timesofindia.indiatimes.com" rel="preconnect">
# <link href="//static.toiimg.com" rel="dns-prefetch">
# <link href="//static.toiimg.com" rel="preconnect">
# <script type="text/javascript" src="/gdpr_js/version-12,minify-1.cms"></script>
# <link media="screen" type="text/css" rel="stylesheet" href="/gdpr_css/version-14,minify-1.cms">
# <script type="text/javascript">
# 	var page = false;
#
#         page = true;
#
#
#
#
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#
#
#             ga('create', 'UA-198011-4', 'auto', {'allowLinker': true});
#             var __ssoid = document.cookie.match(/(?:\s)?ssoid=(\w+);?/);
#             var __prc = document.cookie.match(/(?:\s)?prc=(\w+);?/);
#             if(!!(__ssoid)) {
#                 ga('set', 'userId', __ssoid[1]);
#                 ga('set', 'dimension21', 1);
#                 ga('set', 'dimension22', __ssoid[1]);
#                 ga('set', 'dimension10', ((__prc && __prc[1]) ? __prc[1] : 0));
#             }
#             else{
#                 /*For not logged-in user passing -1 - JIRA:TOIPR-45894*/
#                 ga('set', 'dimension10', -1);
#                 ga('set', 'dimension21', 0);
#             }
#             ga('require', 'linker');
#             ga('linker:autoLink', ['timesofindia.com', 'gocricket.com'] );
#             ga('require', 'displayfeatures');
#
#
#                         ga('require', 'GTM-KCRX3PN');
#
#
#                     ga('set', 'dimension8', 'HomePage');
#
#
#           ga('set', 'dimension9', 'homepage');
#
#
#         if (window.TimesGDPR && TimesGDPR.common.consentModule.gdprCallback){
#             TimesGDPR.common.consentModule.gdprCallback(function(dataObj){
#                 if (dataObj.isEUuser){
#                     ga('set', 'anonymizeIp', true);
#                 }
#
#
#                     ga('send', 'pageview');
#
#
#             });
#         }else{
#             /*
#             *geo ip call failed
#             * show EU
#             */
#             ga('set', 'anonymizeIp', true);
#
#
#                 ga('send', 'pageview');
#
#
#         }
#         var _gaq = Object();
#         _gaq.push = function(ob){
#         	try{
#         	    if(ob[0]=="_trackPageview"){
#
#
#                     ga('send', 'pageview', ob[1]?ob[1]:undefined);
#
#
#         	    }else if(ob[5]){
#         	        ga('send', 'event', ob[1]?ob[1]:undefined, ob[2]?ob[2]:undefined, ob[3]?ob[3]:undefined, {'nonInteraction': 1});
#         	    }else{
#         	        ga('send', 'event', ob[1]?ob[1]:undefined, ob[2]?ob[2]:undefined, ob[3]?ob[3]:undefined, ob[4]?ob[4]:undefined, ob[5]?ob[5]:undefined);
#         	    }
#         	}catch(e){}
#         };
#         //-- Begin comScore Tag --
#
#          window._comscore = window._comscore || [];
#         if (window.TimesGDPR  && TimesGDPR.common.consentModule.gdprCallback){
#             TimesGDPR.common.consentModule.gdprCallback(function(dataObj){
#                 var objComScore = { c1: "2", c2: "6036484" }
#                 if (dataObj.isEUuser){
#                     objComScore['cs_ucfr'] = 0;
#                 }
#                 window._comscore.push(objComScore);
#                 function fireComscore(){
#                     (function() {
#             		    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             		    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#             		    el.parentNode.insertBefore(s, el);
#         		    })();
#         		}
#         		window.fireComscore = fireComscore;
#         		fireComscore();
#         		toiprops = window.toiprops || {};
#                 toiprops.comscoreParams = objComScore;
#             });
#         }
#         else
#         {
#             window._comscore = window._comscore || [];
#             function fireComscore(){
#     		  window._comscore.push({ c1: "2", c2: "6036484", 'cs_ucfr': 0 });
#     		  (function() {
#     		    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     		    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     		    el.parentNode.insertBefore(s, el);
#     		  })();
#     		}
#     		fireComscore();
#     		toiprops = window.toiprops || {};
#             toiprops.comscoreParams = { c1: "2", c2: "6036484", 'cs_ucfr': 0 };
#         }
#         //-- End comScore Tag --
#
#
# 	    </script>
# <!--IN Home LIB :-->
# <style>.all-sections{dislay:none;}</style>
# <link rel="manifest" href="/pn_manifest.cms?v=1">
# <script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" async="true" type="text/javascript"></script><script type="text/javascript" data-cfasync="false">(function(w, d) { var s = d.createElement('script'); s.src = '//delivery.adrecover.com/39799/adRecover.js?ts=1570619213772'; s.type = 'text/javascript'; s.async = true; (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s); })(window, document);</script>
# <link href="/prime_banner_css/version-6,minify-1.cms" media="screen" type="text/css" rel="stylesheet"></head><body bgcolor="#EBEBEB" data-page-name="HP">
# <!--geolocation: -->
# <div id="container">
# <style>
# 				     .top_strip{margin:0px auto; }
# 				        .bgImg .top_strip{background:0}
# 				        div#content { z-index: 0 !important; position: static !important; background:none !important;}
# 				        @media screen and (min-width: 768px) and (max-width: 999px) {
# 				       .top_strip{display:none;}
# 				   }
#
# 				    .esi_container{
#     			        width: 100%!important;
#     			        margin-right: 0!important;
#     			    }
# 				</style>
# <!--::::-->
# <div id="div-gpt-ad-1485328452688-0-topband" data-size="[1000, 60]" data-isactive="top_band" data-adsslot="TOI/TOI_ROS_TOP_Strip_1000x60" class="webonly alC"></div>
# <div style="display:none" class="" id="login-popup">
# <button class="close-btn primeclose-btn" type="button">
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 12 12" height="12" width="12">
# <g fill-rule="evenodd" fill="none">
# <path transform="translate(-6 -6)" d="M0 0H24V24H0z"/>
# <path transform="translate(-6 -6)" d="M13.157 12l4.602-4.6a.817.817 0 000-1.16.817.817 0 00-1.157 0L12 10.843 7.398 6.24a.815.815 0 00-1.157 0 .817.817 0 000 1.159l4.602 4.6-4.602 4.6a.817.817 0 000 1.158c.32.322.837.32 1.157 0L12 13.157l4.602 4.6a.814.814 0 001.157 0 .817.817 0 000-1.157L13.157 12z" fill-rule="nonzero" fill="#999"/>
# </g>
# </svg></button>
# <div class="toggle" id="user-sign-in"></div>
# </div>
# <link href="/timespoint_css/version-11,minify-1.cms" rel="stylesheet" type="text/css"><div class="timespoint-wrapper"><div id="times-point-modal"><button type="button" class="close-btn">+</button><h2><i class="icon tp-sprite"></i>TOI TimesPoints</h2><div class="inner-container"><div class="box tab-container"><input checked class="tab" name="tabGroup" id="tab1" type="radio"><label for="tab1">HOW TO EARN</label><input class="tab" name="tabGroup" id="tab2" type="radio"><label for="tab2">MY ACTIVITY</label><input class="tab" name="tabGroup" id="tab3" type="radio"><label for="tab3">FAQs</label><div class="tab-content how-to"><div class="tp-list-wrapper"><ul class="tp-list tp-loading"></ul><div class="text-center"><button class="more-btn" type="button">more</button></div></div><div class="tp-box2"><h4>DAILY CHECK-INS: <strong><span class="checkin-days">0</span>/5 completed</strong></h4></div><div class="checkin-list"><div class="btn-grp"><button class="tp-sprite btn prev" type="button"></button><button class="tp-sprite btn next" type="button"></button></div><div class="checkin-parent tp-loading"></div></div><div style="display:none;" class="point-box checkin-info-login"><p>You must login to keep earning daily check-in points</p></div><div class="point-box checkin-info"><p></p></div><div id="widget-banner"></div><div class="offers-detail"><div class="tp-box2 flexbox justify-between align-center"><h4 data-link="https://www.timespoints.com/products">REDEEM YOUR TIMES POINTS</h4><a rel="noopener nofollow noreferrer" target="_blank" class="view-all-btn" href="https://www.timespoints.com/products?utm_source=TOI&amp;utm_medium=timespoint&amp;utm_campaign=daily_checkin">VIEW ALL</a></div><div class="gift-cards"><ul class="tp-loading"></ul></div></div></div><div class="tab-content activity"><div class="profile"><div class="inner tp-loading"><div class="profile-header flexbox justify-between align-center"><figure><img src="https://static.toiimg.com/photo/63379366.cms"></figure><div class="details"><h3 data-userdetails="name"></h3></div></div><div class="tp-details"><ul class="flexbox"><li><p>Lifetime</p><h3 data-userdetails="lifetime">0</h3></li><li><p>Expired</p><h3 data-userdetails="expired">0</h3></li><li><p>Redeemed</p><h3 data-userdetails="redeemed">0</h3></li></ul></div><div class="tp-footer"><p>Total redeemable TimesPoints</p><div class="flexbox justify-between align-center"><div class="points"><i class="tp-sprite icon"></i><span data-userdetails="redeemable">0</span></div><a class="redeem-btn tp-redeem" href="javascript: void(0)">redeem</a></div></div></div><p class="token-expiry">* TimesPoints expire in 1 year from the day of credit</p></div><div class="tp-box2 flexbox justify-between align-center"><h4>TODAY&rsquo;S ACTIVITY</h4><p class="tp-loading" id="tp-todays-date"></p></div><ul class="tp-list tp-loading"></ul></div><div class="tab-content faq"></div></div><div class="redeem-points-sticky tp-sprite"><a class="tp-btn tp-redeem" href="javascript: void(0)">REDEEM POINTS</a></div></div></div></div><div id="timespoint-popup"><div class="wrapper"><button class="close-btn" type="button"></button><div class="column"><h2><i class="icon tp-sprite"></i><span id="tp-popup-achieved-text">Visit TOI Daily &amp; Earn Times Points</span><span class="check-in-str-popup"></span></h2></div><div class="column bonusWrapper"><div class="tpPointsToolTip"></div><ul class="daily-points"></ul></div><div class="column"><a class="tp-btn" href="javascript:void(0)">KNOW MORE</a></div></div></div><script>
#             $('#times-point .close-btn').click(function() {
#                 $('.timespoint-wrapper').hide();
#             });
#         </script><!--/timespoint_html.cms?v=23potime:4-->
# <div class="top-area">
# <div class="container">
# <div class="row">
# <div class="column">
# <p>Sun, Nov 01, 2020 | Updated 04.39PM IST</p>
# </div>
# <div class="column">
# <div id="widget-head"></div>
# <div class="user_area clearfix">
# <span style="display:none;float:left;" data-plugin="user-isloggedin">
# <div class="user-controls">
# <span class="user_name">HI, <span data-plugin="user-name"></span><i class="icon_down "></i></span>
# <div class="dropdown">
# <ul>
# <li>
# <a pg="#Click-Edit_Profile-1~Header-User_Profile" target="_blank" href="https://jsso.indiatimes.com/sso/identity/profile/edit?channel=toi">Edit Profile</a>
# </li>
# <li>
# <a pg="#Click-My_Times-2~Header-User_Profile" rel="nofollow" href="http://mytimes.indiatimes.com/?channel=toi" target="_blank">My Times</a>
# </li>
# <li class="tp-redeem">
# <a pg="#Click-TP_Redeem-3~Header-User_Profile" rel="nofollow" href="https://www.timespoints.com/#/products?utm_source=TOI&amp;utm_medium=Header_Dropdown&amp;utm_campaign=TOI_HeaderDropdown" target="_blank">Redeem</a>
# </li>
# <li>
# <span pg="#Click-Logout-4~Header-User_Profile" data-plugin="user-logout">LOGOUT</span>
# </li>
# </ul>
# </div>
# </div>
# </span><span pg="#Click-Sign_In~Header-User_Profile" style="display:none;float:left; position: relative;" data-plugin="user-notloggedin" class="logout-window"><span data-plugin="user-login" class="login">Sign In</span></span>
# </div>
# <span data-plugin="nt-centre" class="noti-cnt"><span data-pgTemplate="#Open~Header-Notification" class="jNtBell"><span class="sprite_bg nt"></span><span class="noti-count"></span></span>
# <div class="gd-notification noimageNt">
# <div class="gn-notifyouter jNtDropdown" data-id="dn-nfouter">
# <div class="notification_title">Notification Center</div>
# <div class="jNtList notification-message">
# <div class="jNotificationMsgTemplate mCustomScrollbar _mCS_4">
# <a href="#0">
# <div pg="#Story_View~Header-Notification" class="notify-list">
# <figure class="ntCenterThumb">
# <img src="https://static.toiimg.com/photo/34824568.cms" data-imgsrctemplate="https://static.toiimg.com/thumb/imgsize-193484,msid-#msid#,width-200,resizemode-4/#msid#.jpg" class="jNtThumb"></figure>
# <div class="ntMsgInnerBox">
# <div rodate="" class="text"></div>
# <div class="text jNtText"></div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </span>
# <ul class="sociable">
# <li class="sprite_bg twitter">
# <a href="https://twitter.com/timesofindia" rel="nofollow" pg="#Click-twitter-1~Header-Social" target="_blank"></a>
# </li>
# <li class="sprite_bg fb">
# <a href="https://www.facebook.com/TimesofIndia" rel="nofollow" pg="#Click-fb-2~Header-Social" target="_blank"></a>
# </li>
# <li class="sprite_bg rss">
# <a href="https://timesofindia.indiatimes.com/rss.cms" pg="#Click-rss-4~Header-Social"></a>
# </li>
# <li class="sprite_bg youtube">
# <a rel="nofollow" href="https://www.youtube.com/user/TimesOfIndiaChannel" pg="#Click-youtube5~Header-Social" target="_blank"></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <link media="screen" type="text/css" rel="stylesheet" href="/css_eventspecial/hcls-whiterock,version-70,minify-1.cms"><header id="header" class="sec- whiterock"><div class="main-area"><div class="container"><a class="mobiletopnav" href="javascript:void(0);"></a><div itemtype="https://schema.org/Organization" itemscope="itemscope" itemprop="publisher" class="logo"><meta content="https://timesofindia.indiatimes.com" itemprop="url"><a pg="#Click~Header-Logo" class="main-sprite" href="/"></a><span itemtype="https://schema.org/ImageObject" itemscope="itemscope" itemprop="logo" class="category"><meta content="https://static.toiimg.com/photo/msid-58127550/toilogo.jpg" itemprop="url"><meta content="600" itemprop="width"><meta content="60" itemprop="height"></span><meta content="Times of India" itemprop="name"></div><div class="header-ad"><div class="webonly" data-size="[728, 90]" id="div-gpt-ad-toi-ros-head" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_ATF_728"></div></div></div></div><div class="bottom-area"><div class="container"><div id="allmenu-content" class="allmenu-content"></div><nav id="main-nav"><ul itemtype="http://www.schema.org/SiteNavigationElement" itemscope="itemscope" class="hpnav-ul"><li data-menu-type="two-column" data-id="home" class="nav-home" id="nav-home"><a pg="#Section_View-1~NavBar-level0-Home" href="/"></a><meta itemprop="name" content="Home"><meta itemprop="url" content="https://timesofindia.indiatimes.com"></li><li data-id="48986328" data-menu-type="top-stories" class="nav-Briefs" data-preload="" data-params="preload=1"><a href="/briefs" pg="NavBar-level0-Briefs#Section_View-2">Briefs</a><meta itemprop="name" content="Briefs"><meta itemprop="url" content="https://timesofindia.indiatimes.com/briefs"><div class="dropdown  nav-loading top-stories"></div></li><li data-id="prime_nav" class="nav-TOIPlus toiplus toimainmenu  no-hover"><a href="/toi-plus" pg="NavBar-level0-TOIPlus#Section_View-3">TOIPlus</a><meta itemprop="name" content="TOIPlus"><meta itemprop="url" content="https://timesofindia.indiatimes.com/toi-plus"><div class="dropdown  nav-loading top-stories"></div></li><li data-id="3812890" data-menu-type="two-column" class="nav-Videos"><a href="/videos" pg="NavBar-level0-Videos#Section_View-4">Videos</a><meta itemprop="name" content="Videos"><meta itemprop="url" content="https://timesofindia.indiatimes.com/videos"><div class="dropdown two-column"><div class="left-column simple-list"><ul><li data-id="4762524"><a href="/videos/top-videos" pg="NavBar-level0-Videos/level1-Top#Section_View-1">Top</a></li><li data-id="3812890"><a href="/videos/trending-videos" pg="NavBar-level0-Videos/level1-Trending#Section_View-2">Trending</a></li><li data-id="3812908"><a href="/videos/entertainment" pg="NavBar-level0-Videos/level1-Entertainment#Section_View-3">Entertainment</a></li><li data-id="77651310"><a href="/videos/astrology" pg="NavBar-level0-Videos/level1-astrology#Section_View-4">astrology</a></li><li data-id="68200753"><a href="/videos/toi-originals" pg="NavBar-level0-Videos/level1-TOI_Originals#Section_View-5">TOI Originals</a></li><li data-id="3812907"><a href="/videos/news" pg="NavBar-level0-Videos/level1-India#Section_View-6">India</a></li><li data-id="68494225"><a href="/videos/amazing-but-true" pg="NavBar-level0-Videos/level1-Amazing_but_true#Section_View-7">Amazing but true</a></li><li data-id="72276370"><a href="/videos/toi-in-depth" pg="NavBar-level0-Videos/level1-Toi_In-Depth#Section_View-8">Toi In-Depth</a></li><li data-id="69646521"><a href="/videos/times-property" pg="NavBar-level0-Videos/level1-Times_property#Section_View-9">Times property</a></li><li data-id="57448618"><a href="/videos/humour" pg="NavBar-level0-Videos/level1-Humour#Section_View-10">Humour</a></li><li data-id="59192346"><a href="/videos/city" pg="NavBar-level0-Videos/level1-City#Section_View-11">City</a></li><li data-id="68200730"><a href="/videos/international" pg="NavBar-level0-Videos/level1-International#Section_View-12">In ...
#             <ul>
#                 {{for items}}
#                 <li data-id="{{:catkey}}">
#                     <a href="{{:link}}">
#                         {{:section}}
#                     </a>
#                 </li>
#                 {{/for}}
#             </ul>
#         </script><script id="multi-list-menu-tmpl" type="text/x-jsrender">
#             {{for lists}}
#                 <h4 class="list-title">{{:title}}</h4>
#                 <ul>
#                     {{for items}}
#                         <li data-id="{{:catkey}}">
#                             <a href="{{:link}}">
#                                 {{:section}}
#                             </a>
#                         </li>
#                     {{/for}}
#                 </ul>
#             {{/for}}
#         </script><script id="two-column-menu-tmpl" type="text/x-jsrender">
#             {{if items.length}}
#                 <ul {{if items[activeIndex].className}}class="gallery {{:items[activeIndex].className}}"{{/if}} {{if items[activeIndex].catkey == 'gadgets'}}class="links-list"{{/if}}>
#                     {{for items[activeIndex].stories ~class=items[activeIndex].className ~domain=items[activeIndex].domain}}
#                         <li {{if !imageurl}}class="no-img"{{/if}}>
#                             <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}" title="{{:title}}>
#                                 {{if ((#index === 0) || (~class === 'videos') || (~class === 'photos'))}}
#                                 <img data-src="{{:imageurl}}" src="https://static.toiimg.com/photo/34824568.cms" alt="{{:title}}" />
#                                 {{/if}}
#                                 {{if !~class}}
#                                     <span>{{:trimmedtitle}}</span>
#                                 {{/if}}
#                             </a>
#                             {{if ~class}}
#                                 <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}">{{:title}}</a>
#                             {{/if}}
#                         </li>
#                     {{/for}}
#                 </ul>
#             {{/if}}
#         </script><script id="top-stories-menu-tmpl" type="text/x-jsrender">
#             <ul {{if className}}class="gallery {{:className}}"{{/if}} {{if catkey == 'gadgets'}}class="links-list"{{/if}}>
#                 {{for stories ~class=className ~domain=domain}}
#                     <li {{if !imageurl}}class="no-img"{{/if}}>
#                         <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}" title="{{:title}}" pg="{{:pg}}">
#                             {{if (imageurl) && ((#index === 0) || (~class === 'videos') || (~class === 'photos'))}}
#                                 <img data-src="{{:imageurl}}" src="https://static.toiimg.com/photo/34824568.cms" alt="{{:title}}" pg="{{:pg}}"/>
#                             {{/if}}
#                             {{if !~class}}
#                                 <span>
#                                     {{if (trimmedtitle)}}
#                                         <span>{{:trimmedtitle}}</span>
#                                     {{else}}
#                                         <span>{{:title}}</span>
#                                     {{/if}}
#                                 </span>
#                             {{/if}}
#
#                         </a>
#                         {{if ~class}}
#                             <a href="{{if ~domain}}{{:~domain}}{{/if}}{{:link}}" pg="{{:pg}}">
#                                 {{if (trimmedtitle)}}
#                                     <span>{{:trimmedtitle}}</span>
#                                 {{else}}
#                                     <span>{{:title}}</span>
#                                 {{/if}}
#                             </a>
#                         {{/if}}
#                     </li>
#                 {{/for}}
#             </ul>
#         </script><script id="external-html-menu-tmpl" type="text/x-jsrender">
#             {{{html}}}
#         </script><script id="error-msg-tmpl" type="text/x-jsrender">
#             <div class="error-msg">Something went wrong. Click here to view <a href="{{:link}}">{{:title}}</a>.</div>
#         </script></div><div class="search-form"><div class="wrapper"><span class="sports-sprite search-btn jSearchLens"> + </span><div class="inner jAutoSuggestorBox"><form class="navsearchboxvalidate" name="frmsearch1" method="post" action="/search.cms" data-plugin="navsearchboxvalidate"><input tabindex="1" id="query" autocomplete="off" name="query" class="textbox jAutoSuggestorInput" type="text"><input value="search" class="submit jSearchSubmit" type="submit"><input type="hidden" value="" name="type"><input type="hidden" value="233446897" name="catkey"><input type="hidden" value="3" name="search"><input type="hidden" value="" name="sitesearch"><input type="hidden" value="1" name="fields"><input type="hidden" value="2" name="searchtype"><input type="hidden" value="2" name="article"><input value="0" type="hidden" name="search1"><br class="clearfix"></form><ul class="searchSuggestions" id="nav_autosuggest_result"></ul></div></div></div></div></header><!--/base_header.cms?version=202&msid=4719157&homepage=TOIHP&head=showleft&rosad=TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_ATF_728&pv=70&hcls=whiterockpotime:6-->
# <script type="text/javascript" src="/ads.cms"></script><script type="text/javascript">
#                 		    $( window ).load(function() {
#                 		        if(typeof window.canRun === "undefined") {
#                 		            $('.header-ad').html('<a href="https://recipes.timesofindia.com/" pg="adblocker#header-ad" target="_blank"><img src="https://static.toiimg.com/photo/66648361.cms" alt="Thousands of Recipes" width="728"></a>')
#                 		        }
#                             });
#                 		</script>
# <div class="adsdivlyr" id="adsdivLyr"></div>
# <div style="opacity: 0; height: 0px;" id="tileyeDiv"></div>
# <div class="adsdivlyr" name="netspidersosh" id="netspidersosh"></div>
# <div id="content">
# <div class="wrapper clearfix">
# <div data-fallback-ad-for="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov1" data-size="[[125, 600], [120, 600]]" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_RHS_125" id="div-gpt-ad-1498641584608-0" style="top:10px;position:fixed;margin-left: 1006px; cursor: pointer; z-index: 1; " class="ros_skinning_rhs webonly"></div>
# <div data-fallback-ad-for="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov1" data-size="[[125, 600], [120, 600]]" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_LHS_125" id="div-gpt-ad-1547448597970-0" style="top:10px;position:fixed;margin-left: -131px; cursor: pointer; z-index: 1; " class="ros_skinning_lhs webonly"></div>
# <style xmlns:g="http://base.google.com/ns/1.0">
#             .liveS_container .close_s{display: block; border: 0; color: #999; text-decoration: none; cursor: pointer; float: right; position: relative; line-height: 22px; margin:3px 10px 1px; box-sizing: border-box;}
# 				.liveS_container .close_s:before{content: "+"; transform: rotate(135deg); font-size: 27px; font-weight: 300; display: block;}
# 				.liveS_container .close_s:hover{text-decoration: none}
#         </style><script>
#            var miniTVType = 'livetvvideo';
# 		    var miniTVScope = '';
# 		    var entertainmentSections = ['1081479906','27975577','2886704'];
# 		    var sponsoredTitle = "";
# 		    var miniTVTitle = "Actor Boman Irani is e-learning at 60!";
# 		    var sponsoredTitleFull = '';
# 		    sponsoredTitle = sponsoredTitle.substring(0,77)+"...";
#
# 		    var isSponsorVideoPlaying = false;
#
#
#
#        </script><script>
#              window.top.adsCallback = function(adtype){
#                     if(typeof adtype!='undefined' && adtype =="gutterclose"){
#                          try{if(primePaymentFlow){primePaymentFlow.show_ad_free_nudge(true)} }catch(e){}
#                     }
#                     if(typeof adtype!='undefined' && adtype =="expandoclose"){
#                         try{if(primePaymentFlow){primePaymentFlow.show_ad_free_nudge(true)}}catch(e){}
#                     }
#                  if(typeof adtype!='undefined' && adtype =="sponsorVid"){
#                    // $(document.getElementById("minitv")).find(".close_v").click();
#                     $(document.getElementById("player")).attr("src", "/sponsortv.cms");
#                  }
#                      if(typeof adtype!='undefined' && adtype =="gutter"){
#              setTimeout(function(){if(typeof redraw_graphs_pollution === 'function'){redraw_graphs_pollution();}},1000);
#              }
#              }
#        </script><input id="specialId_forGeoEvent" type="hidden" value=""><input id="matchId" type="hidden" value="1xp71exk6u"><div id="minitv" data-pagename="home" data-showlivetv="1" data-showevent="0"></div><script src="https://geoapi.indiatimes.com/?cb=1" type="text/javascript"></script><script>
#
# 			    function registerSponsorVid(){
#                     window.console && console.log("*** registerSponsorVid");
#                         setTimeout(function(){
#                             $(document).trigger('MINI_TV_REGISTER', [{source:'sponsorVid'}, 'MINI_TV_LOADED', function(){}]);
#                             $(document).trigger('MINI_TV_EVENTS', [{source: "sponsorVid",id:''}, "VIDEOREADY"]);
#                         }, 100);
#                         setTimeout(function(){
#                             $(document).trigger('MINI_TV_EVENTS', [{source: "sponsorVid",id:''}, "PLAYING"]);
#                         }, 300);
#                 }
# 			    var isMobileDevice = function () {
#                     return (function (a) {
#                         return /(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test(a) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0, 4));
#                     })(navigator.userAgent || navigator.vendor || window.opera);
#                 }
#                 var isTablet = function () {
#             		return( function ( agent ) {
#             			return /(?:ipad|tab)/i.test( agent );
#             		} )( navigator.userAgent || navigator.vendor || window.opera );
#             	}
# 				var miniTV = Object();
# 				miniTV.ajax = function(url,callback){
# 					$.get( url, function( data ) {
# 						callback( data );
# 					});
# 				};
# 				miniTV.hideMiniTvAndLabel = function(){
# 				    $('.livetv_box_label').hide();
#                     $('.livetv_box').hide();
# 				};
# 				miniTV.preinit = function(){
#                   var showLiveTv = $('#minitv').attr('data-showlivetv');
#                   var pagename = $('#minitv').attr('data-pagename');
#                   if(showLiveTv && parseInt(showLiveTv)){
#                       if(pagename == 'home'){
#                        var showLiveTvEvent =  $('#minitv').attr('data-showevent');
#                           switch(showLiveTvEvent){
#                             case 'onscroll':
#                                miniTV.loadLiveTvOnScroll();
#                                break;
#                             case 'timeout':
#                                   setTimeout(miniTV.isOn, 10000);
#                                  break;
#                             default:
#                                 miniTV.isOn();
#                           }
#                       }else{
#                         miniTV.isOn();
#                       }
#                   }
#                 };
# 				miniTV.throttleLiveTvEvents = function(func,limit){
#                  var inThrottle;
#                   return function() {
#                     var context = this;
#                     if (!inThrottle) {
#                       func.call(context);
#                       inThrottle = true;
#                       setTimeout(function(){inThrottle = false; }, limit);
#                     }
#                   }
#                 };
#                 miniTV.loadLiveTvOnScroll = function(){
#                     $(window).on('scroll.livetvinit', function(){
#                             var scrollTop = $(window).scrollTop();
#                             var throttledCb = miniTV.throttleLiveTvEvents(function(){
#                                 if(scrollTop>=600){
#                                    miniTV.isOn();
#                                   $(window).off('scroll.livetvinit');
#                                 }
#                             }, 200);
#                             throttledCb();
#                     });
#                 };
# 				miniTV.isOn = function(){
# 				    if(isMobileDevice() || isTablet() || window.frmapp) {
# 				        return;
# 				    }
#
#
# 				    var url='https://toibnews.timesofindia.indiatimes.com/TOIBNews/home_topcontent_banner.htm';
# 				    if(window.location.host.match(/toidev|jcmsdev/)){
# 				        var pagename = $('#minitv').attr('data-pagename');
# 				        url='/home_topcontent_banner.cms?pagetype=isEnabled&pagename='+pagename;
# 				    }
#
#
#
# 					miniTV.ajax(url,function(data){
# 						data = $.trim(data);
# 						var geoinfo = window.geoinfo;
#             	        var countryCode = ( geoinfo.CountryCode || "" ).toUpperCase();
#             	        var specialId_forGeoEvent =  ( $("#specialId_forGeoEvent").val() || "" ).toUpperCase();
#             	        var matchId = $("#matchId").val() || "";
#             	        if(
#             	            specialId_forGeoEvent
#             	            && countryCode != specialId_forGeoEvent
#             	        ){
#             	            miniTV.hideMiniTvAndLabel();
#                             return;
#             	        }else if( countryCode == 'HK' ){
#             	            miniTV.hideMiniTvAndLabel();
#             	            return;
#             	        }
#
# 						if(toiprops.cookie.get('playvd') && data!=''){
#
# 							$('#minitv').html(data);
# 							$(document).trigger('miniTVVisible');
#
# 							if($('#streaming_box').is(":visible") && $('.livetv_box_label').is(":visible") || $('.livetv_box').is(":visible"))
# 	                        {
# 	                            $('.livetv_box_label').hide();
# 	                            $('.livetv_box').hide();
# 	                       }
#
# 						    if (typeof miniTV.clickLoad == "function") miniTV.clickLoad();
# 						} else if (data!=''){
#
# 							$('#minitv').html(data);
# 							$(document).trigger('miniTVVisible');
#
# 						    if($('#streaming_box').is(":visible") && $('.livetv_box_label').is(":visible") || $('.livetv_box').is(":visible"))
# 	                        {
# 	                            $('.livetv_box_label').hide();
# 	                            $('.livetv_box').hide();
# 	                       }
# 						}
#
#
#         				   if(miniTVType == "sponsoredvideo" && (miniTVScope == "etimes" && ((window.parent.toiprops.subsec1!=undefined && entertainmentSections.indexOf(window.parent.toiprops.subsec1) >=0) || (window.parent.channelname != undefined && window.parent.channelname == 233446897))) && countryCode=="IN")
#         				   {
#         				         if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#         				        {
#         				        	$(".liveS_container").hide();
#         				            if (typeof miniTV.clickLoad == "function") miniTV.clickLoad();
#         				        }
#         				        $("#player").attr("src", "/sponsortv.cms");
#         				        $(".livetv_title").html(sponsoredTitle);
#         				        $(".livetv_title").attr("title",sponsoredTitleFull);
#         				        $("#streaming_box").addClass("sponsoredad");
#         				        isSponsorVideoPlaying = true;
#         				        registerSponsorVid && registerSponsorVid();
#
#         				   }
#         				   else if(miniTVType == "sponsoredvideo" && miniTVScope == "" && countryCode=="IN")
#         				   {
#         				        if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#         				        {
#         				        	$(".liveS_container").hide();
#         				            if (typeof miniTV.clickLoad == "function") miniTV.clickLoad();
#         				        }
#         				         $("#player").attr("src", "/sponsortv.cms");
#         				         $(".livetv_title").html(sponsoredTitle);
#         				         $(".livetv_title").attr("title",sponsoredTitleFull);
#         				         $("#streaming_box").addClass("sponsoredad");
#         				         isSponsorVideoPlaying = true;
#         				         registerSponsorVid && registerSponsorVid();
#         				   }
#         				    else if(miniTVType == "livetvvideo" && (miniTVScope == "etimes" && ((window.parent.toiprops.subsec1!=undefined && entertainmentSections.indexOf(window.parent.toiprops.subsec1) >=0) || (window.parent.channelname != undefined && window.parent.channelname == 233446897))))
#         				   {
#         				         $("#streaming_box").removeClass("sponsoredad");
#         				        isSponsorVideoPlaying = false;
#         				        // do nothing
#         				        if(miniTVTitle == "")
#         				        {
#
#         				            if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#             				        {
#             				        	$(".liveS_container").hide();
#             				        }
#         				        }
#
#         				   }
#         				   else if(miniTVType == "livetvvideo" && miniTVScope == "")
#         				   {
#         				        $("#streaming_box").removeClass("sponsoredad");
#         				        isSponsorVideoPlaying = false;
#         				        // do nothing
#         				        if(miniTVTitle == "")
#         				        {
#
#         				            if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#             				        {
#             				        	$(".liveS_container").hide();
#             				        }
#         				        }
#         				   }
#         				   else if(miniTVType == "livetvvideo" && miniTVScope == "ptgalso")
#         				   {
#         				        $("#streaming_box").removeClass("sponsoredad");
#         				        isSponsorVideoPlaying = false;
#         				        // do nothing
#         				        if(miniTVTitle == "")
#         				        {
#
#         				            if(toiprops.cookie.get('playvd') == undefined || (toiprops.cookie.get('playvd') && toiprops.cookie.get('playvd') != 1))
#             				        {
#             				        	$(".liveS_container").hide();
#             				        }
#         				        }
#         				   }
#         				   else
#         				   {
#         				        //do nothing
#         				        $(".liveS_container").hide();
#         				        $("#minitv").hide()
#         				   }
#         				   try{ if(TimesApps.ad_free_nudge==1){$('#streaming_box').addClass("adjust_nudge")}}catch(e){}
# 					});
# 				};
#
#
# 			        setTimeout(function(){miniTV.preinit();}, 5000);
# 			    </script><!--/home_topcontent_banner.cms?pagename=home&version=15&pagetype=new&source=toipotime:7-->
# <div>
# ...
# </a></li><li><a pg="More_from_TOI-Wattpad#Story_View-4-geturl" title="Last Drop of Water
# " target="_blank" href="https://www.wattpad.com/story/219559488?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Last Drop of Water
# </a></li><li><a pg="More_from_TOI-Wattpad#Story_View-5-geturl" title="Shared Responsibilities" target="_blank" href="https://www.wattpad.com/story/219696671?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Shared Responsibilities</a></li></ul></div><div class="widget"><div class="widget-heading2 clearfix"><a class="more" href="https://www.businessinsider.in?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" pg="More_from_TOI-BusinessInsider#Section_View_More" target="_blank" rel="nofollow">more</a><h3><span><a href="https://www.businessinsider.in?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" pg="More_from_TOI-BusinessInsider#Section_View" target="_blank" rel="nofollow">Business Insider India</a></span></h3></div><ul class="list2"><li class="main-story clearfix"><figure><a href="https://www.businessinsider.in/entertainment/news/darrell-hammond-shared-a-clip-of-his-iconic-snl-sean-connery-impression-in-honor-of-the-late-james-bond-star/articleshow/78981324.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" pg="More_from_TOI-BusinessInsider#Story_View-1-geturl" rel="nofollow"><img src="https://static.toiimg.com/photo/34824568.cms" data-src="/thumb/78981324.cms" alt="Darrell Hammond shared a clip of his iconic 'SNL' Sean Connery impression in honor of the late James Bond star"></a></figure><h3><a pg="More_from_TOI-BusinessInsider#Story_View-1-geturl" title="Darrell Hammond shared a clip of his iconic 'SNL' Sean Connery impression in honor of the late James Bond star" target="_blank" href="https://www.businessinsider.in/entertainment/news/darrell-hammond-shared-a-clip-of-his-iconic-snl-sean-connery-impression-in-honor-of-the-late-james-bond-star/articleshow/78981324.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Darrell Hammond shared a clip of his iconic</a></h3></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-2-geturl" title="Heavy-hitting American boxer Gervonta Davis takes another big step to superstardom with a devastating KO win" target="_blank" href="https://www.businessinsider.in/sports/news/heavy-hitting-american-boxer-gervonta-davis-takes-another-big-step-to-superstardom-with-a-devastating-ko-win/articleshow/78981079.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Heavy-hitting American boxer Gervonta Davis</a></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-3-geturl" title="Covid vaccine trials in AMU from Nov 14" target="_blank" href="https://www.businessinsider.in/india/news/covid-vaccine-trials-in-amu-from-nov-14/articleshow/78978301.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">Covid vaccine trials in AMU from Nov 14</a></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-4-geturl" title="The Biden campaign cancelled events in Texas after a convoy of trucks flying Trump flags surrounded their bus and ran into a person's car, officials say" target="_blank" href="https://www.businessinsider.in/politics/world/news/the-biden-campaign-cancelled-events-in-texas-after-a-convoy-of-trucks-flying-trump-flags-surrounded-their-bus-and-ran-into-a-persons-car-officials-say/articleshow/78977884.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">The Biden campaign cancelled events in Texas</a></li><li><a pg="More_from_TOI-BusinessInsider#Story_View-5-geturl" title="NYC authorities shut down a packed, indoor Halloween party in Brooklyn with nearly 400 guests" target="_blank" href="https://www.businessinsider.in/international/news/nyc-authorities-shut-down-a-packed-indoor-halloween-party-in-brooklyn-with-nearly-400-guests/articleshow/78977111.cms?utm_source=TOInewHP_TILwidget&amp;utm_medium=ABtest&amp;utm_campaign=TOInewHP" rel="nofollow">NYC authorities shut down a packed, indoor</a ...
# <div class="loader alC">
# <img src="https://static.toiimg.com/photo/35958799.cms"></div>
# </div>
# </div>
# </div>
# </div>
# <script defer="1" src="/election_social_js/minify-1,version-4.cms" type="text/javascript"></script><script src="/prime_banner_js/version-24,minify-1.cms" type="text/javascript"></script>
# <div class="wrapper toi_cube_box" id="div-gpt-ad-1576845512809-0" data-size="[1, 1]" data-adsSlot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_Cube_1x1"></div>
# <footer class="new_footer" id="footer">
# <script>
#         (function(){
#           function pingIbeat() {
#             window._pg_endpt=(new Date()).getTime();
#             var e = document.createElement('script');
#             e.setAttribute('language', 'javascript');
#             e.setAttribute('type', 'text/javascript');
#             e.setAttribute('async', 'true');
#             e.setAttribute('src',"https://agi-static.indiatimes.com/cms-common/ibeat.min.js");
#             document.body.appendChild(e);
#           }
#           function _ccaud() {
#             var e = document.createElement('script');
#             e.setAttribute('language', 'javascript');
#             e.setAttribute('type', 'text/javascript');
#             e.setAttribute('async', 'true');
#             e.setAttribute('src',"https://ade.clmbtech.com/cde/ae/2658/var=_ccaud?_u="+encodeURIComponent(window.location.href));
#             document.body.appendChild(e);
#           }
#
#           if (TimesGDPR && TimesGDPR.common.consentModule.gdprCallback){
#                 TimesGDPR.common.consentModule.gdprCallback(function(dataObj){ //Block for EU users
#                     if (dataObj.isEUuser){_ibeat_track= {sCookie: false}}
#                     pingIbeat();
#                 });
#             }else{
#                 _ibeat_track= {sCookie: false};
#                 pingIbeat();
#             }
#             _ccaud()
#         })();
#         </script><style>
#             .video-overlay-wrapper .playlist ul.cvs_wdt li:after, .expand-overlay .playlist ul li:after{width: calc(100% + 20px); height: calc(100% + 20px); left: -10px; top: -10px;}
#         </style><div class="wrapper"><div data-cookie="geolocation" data-size="[1, 1]" data-adsSlot="TOI_Impression_Trackers/TOI_Test_Geo_1x1" data-geo="1|2|3|4|6|7|8" id="div-gpt-ad-1453295401681-0"></div><div data-size="[1, 1]" data-adsSlot="TOI/TOI_ROS/TOI_ROS_Andbeyond_1x1" id="div-gpt-ad-1559800487669-0"></div><div data-size="[1, 1]" data-geo="2|7" data-adsSlot="TOI/TOI_ROS/TOI_ROS_Undertone_1x1" id="div-gpt-ad-1559800489898-0"></div><div data-cookie="geostate" data-size="[1, 1]" data-adsSlot="TOI_Impression_Trackers/TOI_Test_Web_Geo_1x1" data-geo="1|2" id="div-gpt-ad-145329540136376-0"></div><div style="" class="row level1 clearfix"><div class="column"><div class="section"><h2><span>Other Times Group news sites</span></h2><ul><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-The_Economic_Times#Item_View-2-geturl" title="The Economic Times" href="https://economictimes.indiatimes.com" rel="nofollow">The Economic Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Hindi_Economic_Times#Item_View-3-geturl" title="Hindi Economic Times" href="https://economictimes.indiatimes.com/hindi" rel="nofollow">Hindi Economic Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Navbharat_Times#Item_View-4-geturl" title="Navbharat Times" href="https://navbharattimes.indiatimes.com" rel="nofollow">Navbharat Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Maharashtra_Times#Item_View-5-geturl" title="Maharashtra Times" href="https://maharashtratimes.com/" rel="nofollow">Maharashtra Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Vijaya_Karnataka#Item_View-6-geturl" title="Vijaya Karnataka" href="https://vijaykarnataka.com/" rel="nofollow">Vijaya Karnataka</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Telugu_Samayam#Item_View-7-geturl" title="Telugu Samayam" href="https://telugu.samayam.com/" rel="nofollow">Telugu Samayam</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Tamil_Samayam#Item_View-8-geturl" title="Tamil Samayam" href="https://tamil.samayam.com/" rel="nofollow">Tamil Samayam</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Malayalam_Samayam#Item_View-9-geturl" title="Malayalam Samayam" href="https://malayalam.samayam.com/" rel="nofollow">Malayalam Samayam</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Ei_Samay#Item_View-10-geturl" title="Ei Samay" href="https://eisamay.indiatimes.com/" rel="nofollow">Ei Samay</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-I_am_Gujarat#Item_View-11-geturl" title="I am Gujarat" href="https://www.iamgujarat.com/" rel="nofollow">I am Gujarat</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Times_Now#Item_View-12-geturl" title="Times Now" href="https://www.timesnownews.com/" rel="nofollow">Times Now</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Times_Now_Hindi#Item_View-13-geturl" title="Times Now Hindi" href="https://www.timesnowhindi.com/" rel="nofollow">Times Now Hindi</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-TimesPoints#Item_View-14-geturl" title="TimesPoints" href="https://www.timespoints.com/#/products?utm_source=TOI&amp;utm_medium=Footer&amp;utm_campaign=TOI_Footer" rel="nofollow">TimesPoints</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Indiatimes#Item_View-15-geturl" title="Indiatimes" href="https://www.indiatimes.com/" rel="nofollow">Indiatimes</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Brand_Capital#Item_View-16-geturl" title="Brand Capital" href="http://brandcapital.co.in/" rel="nofollow">Brand Capital</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/level1-Education_Times#Item_View-17-geturl" title="Education Times" href="http://www.educationtimes.com/" rel="nofollow">Education Times</a></li><li><a pg="Footer-level0-Other_Times_Group_News_Sites/le ...
#
#                     <span class="temp_h">
#                     {{if cityName}}
#                              {{:cityName}}
#                     {{/if}}
#                     </span>
#                     <span class="temp_g">
#                         <a href="/weather/city-{{:cityName}}.cms" target="_blank">
#                             <span class="icon {{:iconClass}}"></span>
#                             <span class="temp">
#                                 <span class="wdC">{{:tempC}}&#xB0;<small>C</small></span>
#                                 <span class="wdF">{{:tempF}}&#xB0;F</span>
#                             </span>
#                         </a>
#                     </span>
#                     <span class="optionshome">
#                         <a pg="#Change-Fahrenheit~Header-Weather" onclick="$('.wdF').hide();$('.wdC').show();$('#wdCid').hide();$('#wdFid').show();" style="cursor: pointer; display: none;" id="wdCid">°C</a>
#                         <a pg="#Change-Celcius~Header-Weather" onclick="$('.wdC').hide();$('.wdF').show();$('#wdFid').hide();$('#wdCid').show();" style="cursor: pointer;" id="wdFid">&#xB0;F</a>
#                     </span>
#                     <a href="/weather.cms" target="_blank" class="arrow" pg="#Click~Header-Weather">»</a>
#
#             </script><script type="text/javascript">
#
#                 (function(){
#                     var showTOIPlusinNav = false;
#                     if( (["toidev.indiatimes.com", "toistg.indiatimes.com"].indexOf(document.location.hostname) > -1) ){
#                         if(document.location.search.indexOf('geolocation=1') > -1) {
#                             showTOIPlusinNav = true;
#                         }
#                     }
#                     else if(window._geo != 'undefined' && window._geo == '1'){
#                         showTOIPlusinNav = true;
#                     }
#                     if(showTOIPlusinNav){
#                         var toiplusinNavEle = document.querySelector("#main-nav>ul>li.toiplus");
#                         if(typeof(toiplusinNavEle) != 'undefined' && toiplusinNavEle != null){
#                             document.querySelector("#main-nav>ul>li.toiplus").style.display = "inline-block";
#                         }
#                     }
#                 })();
#
#         </script><div class="wrapper"><p>Copyright &copy; 2020 Bennett, Coleman &amp; Co. Ltd. All rights reserved. For reprint rights: <a href="#">Times Syndication Service</a></p></div><!--/toifooter.cms?s=0&version=6&newlogin=potime:4-->
# <!--Server: 130-->
# <link media="screen" type="text/css" rel="stylesheet" href="/slick_css/version-1,minify-1.cms">
# <script src="/slick_min_js_v18/version-1,minify-1.cms" type="text/javascript"></script><script type="text/javascript" src="https://image.timespoints.iimg.in/static/tpsdk/tp-sdk.js"></script><script src="/jsrender/version-1.cms" type="text/javascript"></script><script src="https://jssocdn.indiatimes.com/crosswalk/jsso_crosswalk_legacy_0.5.3.min.js" type="text/javascript"></script><script defer="true" async="true" src="https://www.google.com/recaptcha/api.js"></script>
# <link href="/usermanagementcssv2/version-20,minify-1.cms" media="screen" type="text/css" rel="stylesheet">
# <script type="text/javascript" src="/toi_js/version-589,minify-1.cms"></script><script src="/pn/version-39,minify-1.cms" type="text/javascript"></script><script>
#         (function(){
#           if (TimesGDPR && TimesGDPR.common.consentModule.gdprCallback){
#                 TimesGDPR.common.consentModule.gdprCallback(function(dataObj){ //Block for EU users
#                     var showJs = !dataObj.isEUuser || (dataObj && dataObj.isEUuser && !dataObj.didUserOptOut);
#
#                     if(showJs){
#                         var pbjsEl = document.createElement("script");
#                         pbjsEl.type = "text/javascript";
#                         pbjsEl.async = true;
#                         pbjsEl.src = "https://static.clmbtech.com/ase/2658/3/aa.js";
#                         pbjsEl.onload = function(){
#
#                         }
#                         var pbjsTargetEl = document.getElementsByTagName("head")[0];
#                         pbjsTargetEl.insertBefore(pbjsEl, pbjsTargetEl.firstChild);
#                     }
#                 });
#             }
#         })();
#         </script>
# </footer>
# <script src="/homejs/minify-1,version-455.cms" type="text/javascript"></script><script type="text/javascript">
#                      $('#travelwidget .main-story').addClass("clearfix");
#                  </script>
# <div data-fallback-ads="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_RHS_125$$TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_LHS_125" data-isactive="hp_innov1" id="div-gpt-ad-TOI_HP_NW_OP_Innov1" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov1" class="webonly"></div>
# <div id="div-gpt-ad-TOI_HP_NW_OP_Innov2" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Innov2" class="webonly"></div>
# <div id="div-gpt-ad-TOI_HP_NW_OP_Pop" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Pop" class="webonly"></div>
# <div id="div-gpt-ad-oHP_NW_OP_Shosh" data-adsslot="TOI/TOI_Home/TOI_Home_Home_New/TOI_HP_NW_OP_Shosh" class="webonly"></div>
# </div>
# </body>
# <div xmlns:str="http://exslt.org/strings" class="ad-widget wdgt colombia alC" id="div-gpt-ad---" data-position="" data-slot=""></div><!--/native_content.cms?slot=129105&section=0&String=129105:1potime:6-->
# </html>

# %%
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
raw = BeautifulSoup(html, 'html.parser').get_text()
tokens = word_tokenize(raw)
print(len(tokens))
print(tokens)
# Out:
# 15277
# ['News', '-', 'Latest', 'News', ',', 'Breaking', 'News', ',', 'Bollywood', ',', 'Sports', ',', 'Business', 'and', 'Political', 'News', '|', 'Times', 'of', 'India', 'var', '_sf_async_config', '=', '_sf_async_config', '||', '{', '}', ';', '/**', 'CONFIGURATION', 'START', '**/', '_sf_async_config.uid', '=', '10538', ';', '//', 'ACCOUNT', 'NUMBER', '_sf_async_config.domain', '=', "'timesofindia.indiatimes.com", "'", ';', '//', 'DOMAIN', '_sf_async_config.flickerControl', '=', 'false', ';', '_sf_async_config.useCanonical', '=', 'true', ';', '/**', 'CONFIGURATION', 'END', '**/', 'var', '_sf_startpt', '=', '(', 'new', 'Date', '(', ')', ')', '.getTime', '(', ')', ';', '{', '``', '@', 'context', "''", ':', '``', 'https', ':', '//schema.org/', "''", ',', '``', '@', 'type', "''", ':', '``', 'WebPage', "''", ',', '``', 'name', "''", ':', "''", 'TOI', 'home', 'page', "''", ',', '``', 'description', "''", ':', '``', 'Top', 'News', 'in', 'India', ':', 'Read', 'Latest', 'News', 'on', 'Sports', ',', 'Business', ',', 'Entertainment', ',', 'Blogs', 'and', 'Opinions', 'from', 'leading', 'columnists', '.', 'Times', 'of', 'India', 'brings', 'the', 'Breaking', 'News', 'and', 'Latest', 'News', 'Headlines', 'from', 'India', 'and', 'around', 'the', 'World', '.', '``', ',', '``', 'speakable', "''", ':', '{', '``', '@', 'type', "''", ':', '``', 'SpeakableSpecification', "''", ',', '``', 'cssSelector', "''", ':', '[', '``', '.ga-headlines1', "''", ']', '}', ',', '``', 'url', "''", ':', '``', 'https', ':', '//timesofindia.indiatimes.com', "''", '}', '(', 'function', '(', 'doc', ')', '{', 'var', 'viewport', '=', 'document.getElementById', '(', "'viewport", "'", ')', ';', 'var', 'outerWidth=window.outerWidth', ';', 'if', '(', 'navigator.userAgent.match', '(', '/iPad/i', ')', '||', '(', 'outerWidth', '>', '=768', '&', '&', 'outerWidth', '<', '=999', ')', ')', '{', 'viewport.setAttribute', '(', '``', 'content', "''", ',', '``', 'initial-scale=1.0', ',', 'width=device-width', "''", ')', ';', '}', '}', '(', 'document', ')', ')', ';', 'var', "hdomain='indiatimes.com", "'", ';', 'if', '(', 'document.domain', '!', '=', 'hdomain', ')', '{', 'if', '(', '(', 'document.domain.indexOf', '(', 'hdomain', ')', ')', '!', '=', '-1', ')', '{', 'document.domain', '=', 'hdomain', '}', '}', 'var', 'nsShowCook', '=', '0', '<', '!', '--', '/interstitial_max_count.cms', '?', 'geolocation=potime:35', '--', '>', ';', 'if', '(', 'document.cookie.match', '(', '/', '(', '?', ':', '\\s', ')', '?', 'geostate=', '(', '\\w+', ')', ';', '?', '/', ')', '&', '&', '(', 'document.cookie.match', '(', '/', '(', '?', ':', '\\s', ')', '?', 'geostate=', '(', '\\w+', ')', ';', '?', '/', ')', '[', '1', ']', "==='MP", "'", '||', 'document.cookie.match', '(', '/', '(', '?', ':', '\\s', ')', '?', 'geostate=', '(', '\\w+', ')', ';', '?', '/', ')', '[', '1', ']', "==='DL", "'", ')', ')', '{', 'nsShowCook=10', ';', '}', 'var', "navmsid='122455", "'", ';', 'var', "s='0'||", "''", ';', 'toiprops', '=', 'window.toiprops', '||', '{', '}', ';', 'toiprops.imgdomain', '=', "'https", ':', '//static.toiimg.com', "'", ';', 'toiprops.msid', '=', "'4719157'", 'toiprops.seoLocation', '=', "''", ';', 'toiprops._SCN_pg', '=', '(', 'toiprops._SCN_pg', ')', '?', 'toiprops._SCN_pg', ':', "'Default", "'", ';', 'toiprops.useSSL', '=', "'https", ':', "'", '==', 'document.location.protocol', ';', 'toiprops.bot=/bot|googlebot|crawler|spider|robot|crawling/i.test', '(', 'navigator.userAgent', ')', 'toiprops.subsec1', '=', '47191571', ';', 'toiprops._SCN_pg', '=', "'Default", "'", ';', 'toiprops._Tmpl_pg', '=', "'Default", "'", ';', 'toiprops._AB_version', '=', "'WEB-HPV2", "'", ';', 'toiprops.adFreeLayerSections=1', ';', 'if', '(', 'window._geo', '!', '=', '5', '&', '&', 'window._geo', '!', '=', '1', ')', '{', 'toiprops.toiprebid=1', ';', '}', 'var', 'page', '=', 'false', ';', 'page', '=', 'true', ';', '(', 'function', '(', 'i', ',', 's', ',', 'o', ',', 'g', ',', 'r', ',', 'a', ',', 'm', ')', '{', 'i', '[', "'GoogleAnalyticsObject" ...

# %%
import nltk
tokens = tokens[:10615]
text = nltk.Text(tokens)
text.concordance('News')
# Out:
# Displaying 12 of 12 matches:
#                                      News - Latest News , Breaking News , Boll
#                                      News , Breaking News , Bollywood , Sports
#                                      News , Bollywood , Sports , Business and
#                                      News | Times of India var _sf_async_confi
# page '' , `` description '' : `` Top News in India : Read Latest News on Sport
# : `` Top News in India : Read Latest News on Sports , Business , Entertainment
# . Times of India brings the Breaking News and Latest News Headlines from India
#  brings the Breaking News and Latest News Headlines from India and around the
# test to shore up jobs for locals TOP NEWS STORIES Nov 10 will see NDA win , PM
# lt ; } ENTERTAINMENTCoronavirus live news | IPL Playoffs 2020 | KXIP vs CSK Li
# = { city : '' , exclude : 0 } LATEST NEWS Live : Oppn peddled lies on CAA , Ar
# emands are met : Vijay BainslaLatest news live updates across citiesAggressive
